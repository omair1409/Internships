# %%
import numpy as np
import pandas as pd
from pandas import ExcelWriter
from pandas import ExcelFile

df = pd.read_excel('SportsID - WORKING Sports Camps Master Sheet updated as of 03.27.18.xlsx', sheet_name=2, header=0)

# %%
df
# Out:
#                                         Sports Camp Name Sports Offered  \
# 0           Alabama A&M University 2016 Fundamental Camp       Baseball
# 1      Alabama A&M University 2016 Summer Skills Clin...       Baseball
# 2      Alabama A&M University 2016 Summer Skills Clin...       Baseball
# 3      Alabama A&M University 2016 Summer Skills Clin...       Baseball
# 4                   Alabama A&M University Showcase Camp       Baseball
# ...                                                  ...            ...
# 26375  University of Wyoming - Volleyball Elite Camp ...     Volleyball
# 26376  University of Wyoming - Volleyball Skills Camp...     Volleyball
# 26377  University of Wyoming - Volleyball Skills Camp...     Volleyball
# 26378  University of Wyoming - Volleyball Team Camp (...     Volleyball
# 26379  University of Wyoming - Volleyball Team Camp (...     Volleyball
#
#                                                   Skills  \
# 0                                             all skills
# 1      Techniques, drills and skill specific exercise...
# 2      Techniques, drills and skill specific exercise...
# 3      Techniques, drills and skill specific exercise...
# 4                                             all skills
# ...                                                  ...
# 26375  Camp will involve more advanced skill instruct...
# 26376  Camp are designed for the beginner to intermed...
# 26377  Camp are designed for the beginner to intermed...
# 26378  Camp is a great opportunity for Middle & High ...
# 26379  Camp is a great opportunity for Middle & High ...
#
#                                   Required Skill Level Gender            Age  \
# 0      Novice, Beginner, Intermediate, Advanced, Elite      B      Ages 7-14
# 1                                         Intermediate      B  not available
# 2                                         Intermediate      B  not available
# 3                                         Intermediate      B  not available
# 4      Novice, Beginner, Intermediate, Advanced, Elite      B  not available
# ...                                                ...    ...            ...
# 26375                           Intermediate, Advanced      F      Ages 0-99
# 26376                           Beginner, Intermediate      F      Ages 0-99
# 26377                           Beginner, Intermediate      F      Ages 0-99
# 26378                           Intermediate, Advanced      F      Ages 0-99
# 26379                           Intermediate, Advanced      F      Ages 0-99
#
#                Grade              Schedule Asssociated Organization  \
# 0      not available             Half Week   Alabama A&M University
# 1        Grades 9-12              Full Day   Alabama A&M University
# 2        Grades 9-12              Full Day   Alabama A&M University
# 3        Grades 9-12              Full Day   Alabama A&M University
# 4        Grades 9-12             Half Week   Alabama A&M University
# ...              ...                   ...                      ...
# 26375            NaN  Overnight, Half Week    University of Wyoming
# 26376            NaN   Full Day, Half Week    University of Wyoming
# 26377            NaN  Overnight, Half Week    University of Wyoming
# 26378            NaN   Full Day, Half Week    University of Wyoming
# 26379            NaN  Overnight, Half Week    University of Wyoming
#
#                        Street Address  ... Remarks Added by [VA]  \
# 0      4900 Meridian St N, Huntsville  ...     NaN           Naz
# 1      4900 Meridian St N, Huntsville  ...     NaN           Naz
# 2      4900 Meridian St N, Huntsville  ...     NaN           Naz
# 3      4900 Meridian St N, Huntsville  ...     NaN           Naz
# 4      4900 Meridian St N, Huntsville  ...     NaN           Naz
# ...                               ...  ...     ...           ...
# 26375           1000 E University Ave  ...     NaN           MRA
# 26376           1000 E University Ave  ...     NaN           MRA
# 26377           1000 E University Ave  ...     NaN           MRA
# 26378           1000 E University Ave  ...     NaN           MRA
# 26379           1000 E University Ave  ...     NaN           MRA
#
#                 Date Added Modified by [VA] Date Modified Complete?  \
# 0                      NaN              NaN           NaN       YES
# 1                      NaN              NaN           NaN       YES
# 2                      NaN              NaN           NaN       YES
# 3                      NaN              NaN           NaN       YES
# 4                      NaN              NaN           NaN       YES
# ...                    ...              ...           ...       ...
# 26375  2018-03-22 00:00:00              NaN           NaN       YES
# 26376  2018-03-22 00:00:00              NaN           NaN       YES
# 26377  2018-03-22 00:00:00              NaN           NaN       YES
# 26378  2018-03-22 00:00:00              NaN           NaN       YES
# 26379  2018-03-22 00:00:00              NaN           NaN       YES
#
#       Rechecked by VA       Date Rechecked Rechecking Complete?  \
# 0                 NaN                  NaN                  YES
# 1                 NaN                  NaN                  YES
# 2                 NaN                  NaN                  YES
# 3                 NaN                  NaN                  YES
# 4                 NaN                  NaN                  YES
# ...               ...                  ...                  ...
# 26375             MRA  2018-03-22 00:00:00                  YES
# 26376             MRA  2018-03-22 00:00:00                  YES
# 26377             MRA  2018-03-22 00:00:00                  YES
# 26378             MRA  2018-03-22 00:00:00                  YES
# 26379             MRA  2018-03-22 00:00:00                  YES
#
#       NEW ENTRY ADDED BY VA
# 0                       NaN
# 1                       NaN
# 2                       NaN
# 3                       NaN
# 4                       NaN
# ...                     ...
# 26375                   NaN
# 26376                   NaN
# 26377                   NaN
# 26378                   NaN
# 26379                   NaN
#
# [26380 rows x 31 columns]

# %%
#Grade Column Problem not solved.

# %%
np = df[['Sports Camp Name', 'Sports Offered', 'Skills', 'Required Skill Level','Gender', 'Age', 'Schedule', 'Asssociated Organization', 'City', 'State', 'Region','Capacity', 'Price', 'Contact Person', 'Position of Contact Person', 'Camp Email Address', 'Phone Number','Complete?']]

# %%
np
# Out:
#                                         Sports Camp Name Sports Offered  \
# 0           Alabama A&M University 2016 Fundamental Camp       Baseball
# 1      Alabama A&M University 2016 Summer Skills Clin...       Baseball
# 2      Alabama A&M University 2016 Summer Skills Clin...       Baseball
# 3      Alabama A&M University 2016 Summer Skills Clin...       Baseball
# 4                   Alabama A&M University Showcase Camp       Baseball
# ...                                                  ...            ...
# 26375  University of Wyoming - Volleyball Elite Camp ...     Volleyball
# 26376  University of Wyoming - Volleyball Skills Camp...     Volleyball
# 26377  University of Wyoming - Volleyball Skills Camp...     Volleyball
# 26378  University of Wyoming - Volleyball Team Camp (...     Volleyball
# 26379  University of Wyoming - Volleyball Team Camp (...     Volleyball
#
#                                                   Skills  \
# 0                                             all skills
# 1      Techniques, drills and skill specific exercise...
# 2      Techniques, drills and skill specific exercise...
# 3      Techniques, drills and skill specific exercise...
# 4                                             all skills
# ...                                                  ...
# 26375  Camp will involve more advanced skill instruct...
# 26376  Camp are designed for the beginner to intermed...
# 26377  Camp are designed for the beginner to intermed...
# 26378  Camp is a great opportunity for Middle & High ...
# 26379  Camp is a great opportunity for Middle & High ...
#
#                                   Required Skill Level Gender            Age  \
# 0      Novice, Beginner, Intermediate, Advanced, Elite      B      Ages 7-14
# 1                                         Intermediate      B  not available
# 2                                         Intermediate      B  not available
# 3                                         Intermediate      B  not available
# 4      Novice, Beginner, Intermediate, Advanced, Elite      B  not available
# ...                                                ...    ...            ...
# 26375                           Intermediate, Advanced      F      Ages 0-99
# 26376                           Beginner, Intermediate      F      Ages 0-99
# 26377                           Beginner, Intermediate      F      Ages 0-99
# 26378                           Intermediate, Advanced      F      Ages 0-99
# 26379                           Intermediate, Advanced      F      Ages 0-99
#
#                    Schedule Asssociated Organization        City State Region  \
# 0                 Half Week   Alabama A&M University  Hunstville    AL     SE
# 1                  Full Day   Alabama A&M University  Hunstville    AL     SE
# 2                  Full Day   Alabama A&M University  Hunstville    AL     SE
# 3                  Full Day   Alabama A&M University  Hunstville    AL     SE
# 4                 Half Week   Alabama A&M University  Hunstville    AL     SE
# ...                     ...                      ...         ...   ...    ...
# 26375  Overnight, Half Week    University of Wyoming     Laramie    WY     NW
# 26376   Full Day, Half Week    University of Wyoming     Laramie    WY     NW
# 26377  Overnight, Half Week    University of Wyoming     Laramie    WY     NW
# 26378   Full Day, Half Week    University of Wyoming     Laramie    WY     NW
# 26379  Overnight, Half Week    University of Wyoming     Laramie    WY     NW
#
#       Capacity        Price Contact Person         Position of Contact Person  \
# 0        1-100         $105     Mitch Mill                         Head Coach
# 1        1-100  $100 - $195     Mitch Mill                         Head Coach
# 2        1-100  $100 - $195     Mitch Mill                         Head Coach
# 3        1-100  $100 - $195     Mitch Mill                         Head Coach
# 4        1-100          $80     Mitch Mill                         Head Coach
# ...        ...          ...            ...                                ...
# 26375    1-100          260  Kindra Gillen  Camp Coordinator, Assistant Coach
# 26376    1-100    $235-$275  Kindra Gillen  Camp Coordinator, Assistant Coach
# 26377    1-100          365  Kindra Gillen  Camp Coordinator, Assistant Coach
# 26378    1-100    $235-$275  Kindra Gillen  Camp Coordinator, Assistant Coach
# 26379    1-100          365  Kindra Gillen  Camp Coordinator, Assistant Coach
#
#       Camp Email Address    Phone Number Complete?
# 0          info@aamu.edu  (256) 372-5000       YES
# 1          info@aamu.edu  (256) 372-5000       YES
# 2          info@aamu.edu  (256) 372-5000       YES
# 3          info@aamu.edu  (256) 372-5000       YES
# 4          info@aamu.edu  (256) 372-5000       YES
# ...                  ...             ...       ...
# 26375   kgillen@uwyo.edu    307-766-4805       YES
# 26376   kgillen@uwyo.edu    307-766-4805       YES
# 26377   kgillen@uwyo.edu    307-766-4805       YES
# 26378   kgillen@uwyo.edu    307-766-4805       YES
# 26379   kgillen@uwyo.edu    307-766-4805       YES
#
# [26380 rows x 18 columns]

# %%
np.shape
# Out:
# (26380, 18)

# %%
np1 = np.dropna(subset=['Sports Offered'])

# %%
np1
# Out:
#                                         Sports Camp Name Sports Offered  \
# 0           Alabama A&M University 2016 Fundamental Camp       Baseball
# 1      Alabama A&M University 2016 Summer Skills Clin...       Baseball
# 2      Alabama A&M University 2016 Summer Skills Clin...       Baseball
# 3      Alabama A&M University 2016 Summer Skills Clin...       Baseball
# 4                   Alabama A&M University Showcase Camp       Baseball
# ...                                                  ...            ...
# 26375  University of Wyoming - Volleyball Elite Camp ...     Volleyball
# 26376  University of Wyoming - Volleyball Skills Camp...     Volleyball
# 26377  University of Wyoming - Volleyball Skills Camp...     Volleyball
# 26378  University of Wyoming - Volleyball Team Camp (...     Volleyball
# 26379  University of Wyoming - Volleyball Team Camp (...     Volleyball
#
#                                                   Skills  \
# 0                                             all skills
# 1      Techniques, drills and skill specific exercise...
# 2      Techniques, drills and skill specific exercise...
# 3      Techniques, drills and skill specific exercise...
# 4                                             all skills
# ...                                                  ...
# 26375  Camp will involve more advanced skill instruct...
# 26376  Camp are designed for the beginner to intermed...
# 26377  Camp are designed for the beginner to intermed...
# 26378  Camp is a great opportunity for Middle & High ...
# 26379  Camp is a great opportunity for Middle & High ...
#
#                                   Required Skill Level Gender            Age  \
# 0      Novice, Beginner, Intermediate, Advanced, Elite      B      Ages 7-14
# 1                                         Intermediate      B  not available
# 2                                         Intermediate      B  not available
# 3                                         Intermediate      B  not available
# 4      Novice, Beginner, Intermediate, Advanced, Elite      B  not available
# ...                                                ...    ...            ...
# 26375                           Intermediate, Advanced      F      Ages 0-99
# 26376                           Beginner, Intermediate      F      Ages 0-99
# 26377                           Beginner, Intermediate      F      Ages 0-99
# 26378                           Intermediate, Advanced      F      Ages 0-99
# 26379                           Intermediate, Advanced      F      Ages 0-99
#
#                    Schedule Asssociated Organization        City State Region  \
# 0                 Half Week   Alabama A&M University  Hunstville    AL     SE
# 1                  Full Day   Alabama A&M University  Hunstville    AL     SE
# 2                  Full Day   Alabama A&M University  Hunstville    AL     SE
# 3                  Full Day   Alabama A&M University  Hunstville    AL     SE
# 4                 Half Week   Alabama A&M University  Hunstville    AL     SE
# ...                     ...                      ...         ...   ...    ...
# 26375  Overnight, Half Week    University of Wyoming     Laramie    WY     NW
# 26376   Full Day, Half Week    University of Wyoming     Laramie    WY     NW
# 26377  Overnight, Half Week    University of Wyoming     Laramie    WY     NW
# 26378   Full Day, Half Week    University of Wyoming     Laramie    WY     NW
# 26379  Overnight, Half Week    University of Wyoming     Laramie    WY     NW
#
#       Capacity        Price Contact Person         Position of Contact Person  \
# 0        1-100         $105     Mitch Mill                         Head Coach
# 1        1-100  $100 - $195     Mitch Mill                         Head Coach
# 2        1-100  $100 - $195     Mitch Mill                         Head Coach
# 3        1-100  $100 - $195     Mitch Mill                         Head Coach
# 4        1-100          $80     Mitch Mill                         Head Coach
# ...        ...          ...            ...                                ...
# 26375    1-100          260  Kindra Gillen  Camp Coordinator, Assistant Coach
# 26376    1-100    $235-$275  Kindra Gillen  Camp Coordinator, Assistant Coach
# 26377    1-100          365  Kindra Gillen  Camp Coordinator, Assistant Coach
# 26378    1-100    $235-$275  Kindra Gillen  Camp Coordinator, Assistant Coach
# 26379    1-100          365  Kindra Gillen  Camp Coordinator, Assistant Coach
#
#       Camp Email Address    Phone Number Complete?
# 0          info@aamu.edu  (256) 372-5000       YES
# 1          info@aamu.edu  (256) 372-5000       YES
# 2          info@aamu.edu  (256) 372-5000       YES
# 3          info@aamu.edu  (256) 372-5000       YES
# 4          info@aamu.edu  (256) 372-5000       YES
# ...                  ...             ...       ...
# 26375   kgillen@uwyo.edu    307-766-4805       YES
# 26376   kgillen@uwyo.edu    307-766-4805       YES
# 26377   kgillen@uwyo.edu    307-766-4805       YES
# 26378   kgillen@uwyo.edu    307-766-4805       YES
# 26379   kgillen@uwyo.edu    307-766-4805       YES
#
# [26379 rows x 18 columns]

# %%
np1.shape
# Out:
# (26379, 18)

# %%
import seaborn as sns
import matplotlib.pyplot as plt
sns.set(style="darkgrid")
plt.figure(figsize=(40,23))
ax = sns.countplot(x="Sports Offered", data=np1)

# %%
# As we can see there are more camps available for Baseball, Basketball, soccer and Tennis

# %%
plt.figure(figsize=(18,6))
sns.countplot(x='localization',data=df,hue="age")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-11-15930cd86f7f> in <module>
#       1 plt.figure(figsize=(18,6))
# ----> 2 sns.countplot(x='localization',data=df,hue="age")
#
# ~\anaconda3\lib\site-packages\seaborn\categorical.py in countplot(x, y, hue, data, order, hue_order, orient, color, palette, saturation, dodge, ax, **kwargs)
#    3553                           estimator, ci, n_boot, units, seed,
#    3554                           orient, color, palette, saturation,
# -> 3555                           errcolor, errwidth, capsize, dodge)
#    3556
#    3557     plotter.value_label = "count"
#
# ~\anaconda3\lib\site-packages\seaborn\categorical.py in __init__(self, x, y, hue, data, order, hue_order, estimator, ci, n_boot, units, seed, orient, color, palette, saturation, errcolor, errwidth, capsize, dodge)
#    1613         """Initialize the plotter."""
#    1614         self.establish_variables(x, y, hue, data, orient,
# -> 1615                                  order, hue_order, units)
#    1616         self.establish_colors(color, palette, saturation)
#    1617         self.estimate_statistic(estimator, ci, n_boot, seed)
#
# ~\anaconda3\lib\site-packages\seaborn\categorical.py in establish_variables(self, x, y, hue, data, orient, order, hue_order, units)
#     150                 if isinstance(var, str):
#     151                     err = "Could not interpret input '{}'".format(var)
# --> 152                     raise ValueError(err)
#     153
#     154             # Figure out the plotting orientation
#
# ValueError: Could not interpret input 'localization'

# %%
np1
# Out:
#                                         Sports Camp Name  Sports Offered  \
# 0           Alabama A&M University 2016 Fundamental Camp               0
# 1      Alabama A&M University 2016 Summer Skills Clin...               0
# 2      Alabama A&M University 2016 Summer Skills Clin...               0
# 3      Alabama A&M University 2016 Summer Skills Clin...               0
# 4                   Alabama A&M University Showcase Camp               0
# 5      Alabama State University -Blue Chip Prospect S...               0
# 6                Alabama State University -Prospect Camp               0
# 7      America's Baseball Camps - Summer High School ...               0
# 8      America's Baseball Camps - Troy Baseball Winte...               0
# 9      America's Baseball Camps - Winter High School ...               0
# 10               Lawson State Baseball Prospect Showcase               0
# 11                       Shelton State Baseball Showcase               0
# 12     Shelton State Community College - Baseball Sum...               0
# 13     Shelton State Community College - Baseball Sum...               0
# 14     Troy University - Mark Smartt Baseball Camp Su...               0
# 15     Troy University - Mark Smartt Baseball Camp Su...               0
# 16     Troy University - Mark Smartt Baseball Camp Su...               0
# 17     Troy University - Mark Smartt Baseball Camp Su...               0
# 18     Troy University - Mark Smartt Baseball Camp Su...               0
# 19     Troy University - Mark Smartt Baseball Camp Tr...               0
# 20     Troy University - Mark Smartt Baseball Camp Tr...               0
# 21        US Baseball Academy -  Auburn Hitting Sessions               0
# 22         US Baseball Academy - Auburn Catcher Sessions               0
# 23         US Baseball Academy - Auburn Catcher Sessions               0
# 24         US Baseball Academy - Auburn Catcher Sessions               0
# 25         US Baseball Academy - Auburn Catcher Sessions               0
# 26         US Baseball Academy - Auburn Catcher Sessions               0
# 27         US Baseball Academy - Auburn Catcher Sessions               0
# 28         US Baseball Academy - Auburn Catcher Sessions               0
# 29         US Baseball Academy - Auburn Catcher Sessions               0
# ...                                                  ...             ...
# 26350  University of Wyoming - Soccer Future Pokes Ca...              19
# 26351  University of Wyoming - Soccer Future Pokes Ca...              19
# 26352  University of Wyoming - Soccer ID/Individual C...              19
# 26353  University of Wyoming - Soccer ID/Individual C...              19
# 26354  University of Wyoming - Soccer Team Camp (Comm...              19
# 26355  University of Wyoming - Soccer Team Camp (Over...              19
# 26356                University of Wyoming - Swim Camp 1              22
# 26357                University of Wyoming - Swim Camp 2              22
# 26358  University of Wyoming - Swimming Start and Tur...              22
# 26359  University of Wyoming - Swimming Start and Tur...              22
# 26360  University of Wyoming - Junior Tennis Cody/ Po...              23
# 26361  University of Wyoming - Junior Tennis Laramie ...              23
# 26362  University of Wyoming - Junior Tennis Laramie ...              23
# 26363  University of Wyoming - Junior Tennis Rock Spr...              23
# 26364  University of Wyoming - Junior Tennis Sheridan...              23
# 26365  Central Wyoming College - Volleyball Skills Ca...              25
# 26366  Central Wyoming College - Volleyball Skills Ca...              25
# 26367  Eastern Wyoming College - Volleyball Advanced ...              25
# 26368  Eastern Wyoming College - Volleyball Beginner ...              25
# 26369  Eastern Wyoming College - Volleyball Setter/Li...              25
# 26370  Laramie County Community College - Elite Skill...              25
# 26371  Laramie County Community College - Elite Skill...              25
# 26372  Laramie County Community College - Elite Skill...              25
# 26373  Laramie County Community College - Elite Skill...              25
# 26374  University of Wyoming - Volleyball Elite Camp ...              25
# 26375  University of Wyoming - Volleyball Elite Camp ...              25
# 26376  University of Wyoming - Volleyball Skills Camp...              25
# 26377  University of Wyoming - Volleyball Skills Camp...              25
# 26378  University of Wyoming - Volleyball Team Camp (...              25
# 26379  University of Wyoming - Volleyball Team Camp (...              25
#
#                                                   Skills  \
# 0                                             all skills
# 1      Techniques, drills and skill specific exercise...
# 2      Techniques, drills and skill specific exercise...
# 3      Techniques, drills and skill specific exercise...
# 4                                             all skills
# 5                                             all skills
# 6                                             all skills
# 7                                             all skills
# 8                                             all skills
# 9                                             all skills
# 10                                            all skills
# 11     Pro-style workout, assessment of skills, and g...
# 12                                            all skills
# 13                                            all skills
# 14                                     baseball training
# 15                                     baseball training
# 16                                     baseball training
# 17                                     baseball training
# 18                                     baseball training
# 19                                     baseball training
# 20                                     baseball training
# 21                                               Hitting
# 22                                              Catching
# 23                                              Catching
# 24                                              Catching
# 25                                              Catching
# 26                                              Catching
# 27                                              Catching
# 28                                              Catching
# 29                                              Catching
# ...                                                  ...
# 26350                  Fundamentals and Basics of Soccer
# 26351                  Fundamentals and Basics of Soccer
# 26352                  Fundamentals and Basics of Soccer
# 26353                  Fundamentals and Basics of Soccer
# 26354                  Fundamentals and Basics of Soccer
# 26355                  Fundamentals and Basics of Soccer
# 26356  Swimmers will receive intensive training sessi...
# 26357  Swimmers will receive intensive training sessi...
# 26358  Swimmers will receive intensive training sessi...
# 26359  Swimmers will receive intensive training sessi...
# 26360  To provide every tennis player an opportunity ...
# 26361  To provide every tennis player an opportunity ...
# 26362  To provide every tennis player an opportunity ...
# 26363  To provide every tennis player an opportunity ...
# 26364  To provide every tennis player an opportunity ...
# 26365              Fundamentals and Basics of Volleyball
# 26366              Fundamentals and Basics of Volleyball
# 26367  Focus will be directed towards refining indivi...
# 26368  Camp offers basic skill development including:...
# 26369  Offers intense technical and tactical training...
# 26370  Camp is for the competitive volleyball player ...
# 26371  Camp is for the competitive volleyball player ...
# 26372  Camp is for the competitive volleyball player ...
# 26373  Camp is for the competitive volleyball player ...
# 26374  Camp will involve more advanced skill instruct...
# 26375  Camp will involve more advanced skill instruct...
# 26376  Camp are designed for the beginner to intermed...
# 26377  Camp are designed for the beginner to intermed...
# 26378  Camp is a great opportunity for Middle & High ...
# 26379  Camp is a great opportunity for Middle & High ...
#
#                                   Required Skill Level Gender            Age  \
# 0      Novice, Beginner, Intermediate, Advanced, Elite      B      Ages 7-14
# 1                                         Intermediate      B  not available
# 2                                         Intermediate      B  not available
# 3                                         Intermediate      B  not available
# 4      Novice, Beginner, Intermediate, Advanced, Elite      B  not available
# 5                                               Others      B     ages 14-18
# 6                                               Others      B     ages 14-18
# 7      Novice, Beginner, Intermediate, Advanced, Elite      M  not available
# 8      Novice, Beginner, Intermediate, Advanced, Elite      M      ages 6-12
# 9      Novice, Beginner, Intermediate, Advanced, Elite      M  not available
# 10     Novice, Beginner, Intermediate, Advanced, Elite      M  not available
# 11                                              Others      B  not available
# 12     Novice, Beginner, Intermediate, Advanced, Elite      B      Ages 6-17
# 13     Novice, Beginner, Intermediate, Advanced, Elite      B      Ages 6-17
# 14     Novice, Beginner, Intermediate, Advanced, Elite      M  not available
# 15     Novice, Beginner, Intermediate, Advanced, Elite      M  not available
# 16     Novice, Beginner, Intermediate, Advanced, Elite      M  not available
# 17     Novice, Beginner, Intermediate, Advanced, Elite      M  not available
# 18     Novice, Beginner, Intermediate, Advanced, Elite      M  not available
# 19     Novice, Beginner, Intermediate, Advanced, Elite      M      ages 9-12
# 20     Novice, Beginner, Intermediate, Advanced, Elite      M      ages 5-11
# 21     Novice, Beginner, Intermediate, Advanced, Elite      B  not available
# 22     Novice, Beginner, Intermediate, Advanced, Elite      B  not available
# 23     Novice, Beginner, Intermediate, Advanced, Elite      B  not available
# 24     Novice, Beginner, Intermediate, Advanced, Elite      B  not available
# 25     Novice, Beginner, Intermediate, Advanced, Elite      B  not available
# 26     Novice, Beginner, Intermediate, Advanced, Elite      B  not available
# 27     Novice, Beginner, Intermediate, Advanced, Elite      B  not available
# 28     Novice, Beginner, Intermediate, Advanced, Elite      B  not available
# 29     Novice, Beginner, Intermediate, Advanced, Elite      B  not available
# ...                                                ...    ...            ...
# 26350                 Beginner, Intermediate, Advanced      B      Ages 4-13
# 26351                 Beginner, Intermediate, Advanced      B      Ages 4-13
# 26352                 Beginner, Intermediate, Advanced      B     Ages 12-17
# 26353                 Beginner, Intermediate, Advanced      B     Ages 12-17
# 26354                 Beginner, Intermediate, Advanced      B     Ages 12-17
# 26355                 Beginner, Intermediate, Advanced      B     Ages 12-17
# 26356                 Beginner, Intermediate, Advanced      B      Ages 0-99
# 26357                 Beginner, Intermediate, Advanced      B      Ages 0-99
# 26358                 Beginner, Intermediate, Advanced      B      Ages 0-99
# 26359                 Beginner, Intermediate, Advanced      B      Ages 0-99
# 26360                 Beginner, Intermediate, Advanced      B      Ages 7-18
# 26361                 Beginner, Intermediate, Advanced      B      Ages 7-18
# 26362                 Beginner, Intermediate, Advanced      B      Ages 7-18
# 26363                 Beginner, Intermediate, Advanced      B      Ages 7-18
# 26364                 Beginner, Intermediate, Advanced      B      Ages 7-18
# 26365                 Beginner, Intermediate, Advanced      B            NaN
# 26366                 Beginner, Intermediate, Advanced      B            NaN
# 26367                 Beginner, Intermediate, Advanced      B      Ages 0-99
# 26368                 Beginner, Intermediate, Advanced      B            NaN
# 26369                 Beginner, Intermediate, Advanced      B            NaN
# 26370                                  Advanced, Elite      F            NaN
# 26371                                  Advanced, Elite      F            NaN
# 26372                                  Advanced, Elite      F            NaN
# 26373                                  Advanced, Elite      F            NaN
# 26374                           Intermediate, Advanced      F      Ages 0-99
# 26375                           Intermediate, Advanced      F      Ages 0-99
# 26376                           Beginner, Intermediate      F      Ages 0-99
# 26377                           Beginner, Intermediate      F      Ages 0-99
# 26378                           Intermediate, Advanced      F      Ages 0-99
# 26379                           Intermediate, Advanced      F      Ages 0-99
#
#                    Schedule          Asssociated Organization          City  \
# 0                 Half Week            Alabama A&M University    Hunstville
# 1                  Full Day            Alabama A&M University    Hunstville
# 2                  Full Day            Alabama A&M University    Hunstville
# 3                  Full Day            Alabama A&M University    Hunstville
# 4                 Half Week            Alabama A&M University    Hunstville
# 5                 Half Week  Wheeler-Watkins Baseball Complex    Montgomery
# 6                 Half Week  Wheeler-Watkins Baseball Complex    Montgomery
# 7                  Full Day                   Troy University          Troy
# 8                 Half Week   Riddle-Pace Field- Troy Alabama          Troy
# 9                  Full Day   Riddle-Pace Field- Troy Alabama          Troy
# 10                   Others    Lawson State Community College    Birmingham
# 11                Half Week   Shelton State Community College    Tiscaloosa
# 12                Half Week   Shelton State Community College    Tuscaloosa
# 13                Half Week   Shelton State Community College    Tuscaloosa
# 14                Half Week                   Troy University          Troy
# 15                Half Week                   Troy University          Troy
# 16                Half Week                   Troy University          Troy
# 17                Half Week                   Troy University          Troy
# 18                Half Week                   Troy University          Troy
# 19                Half Week                   Troy University          Troy
# 20                Half Week                   Troy University          Troy
# 21                 Full Day               US Baseball Academy        Auburn
# 22                 Full Day               US Baseball Academy        Auburn
# 23                 Full Day               US Baseball Academy        Auburn
# 24                 Full Day               US Baseball Academy        Auburn
# 25                 Full Day               US Baseball Academy        Auburn
# 26                 Full Day               US Baseball Academy        Auburn
# 27                 Full Day               US Baseball Academy        Auburn
# 28                 Full Day               US Baseball Academy        Auburn
# 29                 Full Day               US Baseball Academy        Auburn
# ...                     ...                               ...           ...
# 26350   Half Day, Half Week             University of Wyoming       Laramie
# 26351   Half Day, Half Week             University of Wyoming       Laramie
# 26352   Full Day, Half Week             University of Wyoming       Laramie
# 26353  Overnight, Half Week             University of Wyoming       Laramie
# 26354   Full Day, Half Week             University of Wyoming       Laramie
# 26355  Overnight, Half Week             University of Wyoming       Laramie
# 26356             Full Week             University of Wyoming       Laramie
# 26357             Full Week             University of Wyoming       Laramie
# 26358             Half Week             University of Wyoming       Laramie
# 26359             Half Week             University of Wyoming       Laramie
# 26360             Full Week             University of Wyoming          Cody
# 26361             Full Week             University of Wyoming       Laramie
# 26362             Full Week             University of Wyoming       Laramie
# 26363             Full Week             University of Wyoming  Rock Springs
# 26364             Full Week             University of Wyoming      Sheridan
# 26365              Half Day           Central Wyoming College      Riverton
# 26366              Full Day           Central Wyoming College      Riverton
# 26367   Half Day, Half Week           Eastern Wyoming College    Torrington
# 26368   Half Day, Half Week           Eastern Wyoming College    Torrington
# 26369   Half Day, Half Week           Eastern Wyoming College    Torrington
# 26370             Half Week  Laramie County Community College      Cheyenne
# 26371             Half Week  Laramie County Community College      Cheyenne
# 26372             Half Week  Laramie County Community College      Cheyenne
# 26373             Half Week  Laramie County Community College      Cheyenne
# 26374   Full Day, Half Week             University of Wyoming       Laramie
# 26375  Overnight, Half Week             University of Wyoming       Laramie
# 26376   Full Day, Half Week             University of Wyoming       Laramie
# 26377  Overnight, Half Week             University of Wyoming       Laramie
# 26378   Full Day, Half Week             University of Wyoming       Laramie
# 26379  Overnight, Half Week             University of Wyoming       Laramie
#
#       State Region        Price    Contact Person  \
# 0        AL     SE         $105        Mitch Mill
# 1        AL     SE  $100 - $195        Mitch Mill
# 2        AL     SE  $100 - $195        Mitch Mill
# 3        AL     SE  $100 - $195        Mitch Mill
# 4        AL     SE          $80        Mitch Mill
# 5        AL     SE          175     not available
# 6        AL     SE          250     not available
# 7        AL     SE          110        Rob Avilla
# 8        AL     SE           80        Rob Avilla
# 9        AL     SE          110        Rob Avilla
# 10       AL     SE         $100       Blake Lewis
# 11       AL     SE         $150      Bobby Sprowl
# 12       AL     SE          NaN      Bobby Sprowl
# 13       AL     SE          NaN      Bobby Sprowl
# 14       AL     SE          110     Brad Phillips
# 15       AL     SE          250     Brad Phillips
# 16       AL     SE          250     Brad Phillips
# 17       AL     SE          250     Brad Phillips
# 18       AL     SE          350     Brad Phillips
# 19       AL     SE          250     Brad Phillips
# 20       AL     SE          250     Brad Phillips
# 21       AL     SE    $139-$317        Jim Miksis
# 22       AL     SE    $139-$317        Jim Miksis
# 23       AL     SE    $139-$317        Jim Miksis
# 24       AL     SE    $139-$317        Jim Miksis
# 25       AL     SE    $139-$317        Jim Miksis
# 26       AL     SE    $139-$317        Jim Miksis
# 27       AL     SE    $139-$317        Jim Miksis
# 28       AL     SE    $139-$317        Jim Miksis
# 29       AL     SE    $139-$317        Jim Miksis
# ...     ...    ...          ...               ...
# 26350    WY     NW     $95-$135    Peter Cuadrado
# 26351    WY     NW     $95-$135    Peter Cuadrado
# 26352    WY     NW          360    Peter Cuadrado
# 26353    WY     NW          415    Peter Cuadrado
# 26354    WY     NW          290    Peter Cuadrado
# 26355    WY     NW          335    Peter Cuadrado
# 26356    WY     NW    $175-$490       Tom Johnson
# 26357    WY     NW    $175-$490       Tom Johnson
# 26358    WY     NW    $175-$490       Tom Johnson
# 26359    WY     NW    $175-$490       Tom Johnson
# 26360    WY     NW          235       Dean Clower
# 26361    WY     NW          295       Dean Clower
# 26362    WY     NW          295       Dean Clower
# 26363    WY     NW          235       Dean Clower
# 26364    WY     NW          235       Dean Clower
# 26365    WY     NW           20  Darshaya Gallard
# 26366    WY     NW           30  Darshaya Gallard
# 26367    WY     NW           65    Julie Sherbeyn
# 26368    WY     NW           65    Julie Sherbeyn
# 26369    WY     NW           65    Julie Sherbeyn
# 26370    WY     NW          120     Austin Albers
# 26371    WY     NW          120     Austin Albers
# 26372    WY     NW          200     Austin Albers
# 26373    WY     NW          200     Austin Albers
# 26374    WY     NW    $130-$180     Kindra Gillen
# 26375    WY     NW          260     Kindra Gillen
# 26376    WY     NW    $235-$275     Kindra Gillen
# 26377    WY     NW          365     Kindra Gillen
# 26378    WY     NW    $235-$275     Kindra Gillen
# 26379    WY     NW          365     Kindra Gillen
#
#               Position of Contact Person           Camp Email Address  \
# 0                             Head Coach                info@aamu.edu
# 1                             Head Coach                info@aamu.edu
# 2                             Head Coach                info@aamu.edu
# 3                             Head Coach                info@aamu.edu
# 4                             Head Coach                info@aamu.edu
# 5                          not available  bamastatebaseball@gmail.com
# 6                          not available  bamastatebaseball@gmail.com
# 7                                  Coach                          NaN
# 8                                  Coach                          NaN
# 9                                  Coach                          NaN
# 10                            Head Coach       blewis@lawsonstate.edu
# 11                            Head Coach     rsprowl@sheltonstate.edu
# 12                                   NaN     rsprowl@sheltonstate.edu
# 13                                   NaN     rsprowl@sheltonstate.edu
# 14                                 Coach       bphillips8635@troy.edu
# 15                                 Coach       bphillips8635@troy.edu
# 16                                 Coach       bphillips8635@troy.edu
# 17                                 Coach       bphillips8635@troy.edu
# 18                                 Coach       bphillips8635@troy.edu
# 19                                 Coach       bphillips8635@troy.edu
# 20                                 Coach       bphillips8635@troy.edu
# 21                            Head Coach   info@usbaseballacademy.com
# 22                            Head Coach   info@usbaseballacademy.com
# 23                            Head Coach   info@usbaseballacademy.com
# 24                            Head Coach   info@usbaseballacademy.com
# 25                            Head Coach   info@usbaseballacademy.com
# 26                            Head Coach   info@usbaseballacademy.com
# 27                            Head Coach   info@usbaseballacademy.com
# 28                            Head Coach   info@usbaseballacademy.com
# 29                            Head Coach   info@usbaseballacademy.com
# ...                                  ...                          ...
# 26350                         Head Coach            pcuadrad@uwyo.edu
# 26351                         Head Coach            pcuadrad@uwyo.edu
# 26352                         Head Coach            pcuadrad@uwyo.edu
# 26353                         Head Coach            pcuadrad@uwyo.edu
# 26354                         Head Coach            pcuadrad@uwyo.edu
# 26355                         Head Coach            pcuadrad@uwyo.edu
# 26356          Head Coach, Camp Director                tomj@uwyo.edu
# 26357          Head Coach, Camp Director                tomj@uwyo.edu
# 26358          Head Coach, Camp Director                tomj@uwyo.edu
# 26359          Head Coach, Camp Director                tomj@uwyo.edu
# 26360                         Head Coach             eclower@uwyo.edu
# 26361                         Head Coach             eclower@uwyo.edu
# 26362                         Head Coach             eclower@uwyo.edu
# 26363                         Head Coach             eclower@uwyo.edu
# 26364                         Head Coach             eclower@uwyo.edu
# 26365                         Head Coach             dgallard@cwc.edu
# 26366                         Head Coach             dgallard@cwc.edu
# 26367                         Head Coach    julie.sherbeyn@ewc.wy.edu
# 26368                         Head Coach    julie.sherbeyn@ewc.wy.edu
# 26369                         Head Coach    julie.sherbeyn@ewc.wy.edu
# 26370      Head Coach Women's Volleyball          aalbers@lccc.wy.edu
# 26371      Head Coach Women's Volleyball          aalbers@lccc.wy.edu
# 26372      Head Coach Women's Volleyball          aalbers@lccc.wy.edu
# 26373      Head Coach Women's Volleyball          aalbers@lccc.wy.edu
# 26374  Camp Coordinator, Assistant Coach             kgillen@uwyo.edu
# 26375  Camp Coordinator, Assistant Coach             kgillen@uwyo.edu
# 26376  Camp Coordinator, Assistant Coach             kgillen@uwyo.edu
# 26377  Camp Coordinator, Assistant Coach             kgillen@uwyo.edu
# 26378  Camp Coordinator, Assistant Coach             kgillen@uwyo.edu
# 26379  Camp Coordinator, Assistant Coach             kgillen@uwyo.edu
#
#                       Phone Number Complete?
# 0                   (256) 372-5000       YES
# 1                   (256) 372-5000       YES
# 2                   (256) 372-5000       YES
# 3                   (256) 372-5000       YES
# 4                   (256) 372-5000       YES
# 5                     334.603.3094       YES
# 6                     334.603.3094       YES
# 7                   (800) 222-8152       YES
# 8                   (800) 222-8152       YES
# 9                   (800) 222-8152       YES
# 10                    205-929-6489       YES
# 11     205.391.2206 / 205.886.6240       YES
# 12                    205-391-2206       YES
# 13                    205-391-2206       YES
# 14                    334-670-5705       YES
# 15                    334-670-5705       YES
# 16                    334-670-5705       YES
# 17                    334-670-5705       YES
# 18                    334-670-5705       YES
# 19                    334-670-5705       YES
# 20                    334-670-5705       YES
# 21                   (866)622-4487       YES
# 22                   (866)622-4487       YES
# 23                   (866)622-4487       YES
# 24                   (866)622-4487       YES
# 25                   (866)622-4487       YES
# 26                   (866)622-4487       YES
# 27                   (866)622-4487       YES
# 28                   (866)622-4487       YES
# 29                   (866)622-4487       YES
# ...                            ...       ...
# 26350                 307-766-5508       YES
# 26351                 307-766-5508       YES
# 26352                 307-766-5508       YES
# 26353                 307-766-5508       YES
# 26354                 307-766-5508       YES
# 26355                 307-766-5508       YES
# 26356                 307-766-6265       YES
# 26357                 307-766-6265       YES
# 26358                 307-766-6265       YES
# 26359                 307-766-6265       YES
# 26360                 307-766-4331       YES
# 26361                 307-766-4331       YES
# 26362                 307-766-4331       YES
# 26363                 307-766-4331       YES
# 26364                 307-766-4331       YES
# 26365                 307-855-2322       YES
# 26366                 307-855-2322       YES
# 26367               1.307.575.5083       YES
# 26368               1.307.575.5083       YES
# 26369               1.307.575.5083       YES
# 26370                 307-778-4339       YES
# 26371                 307-778-4339       YES
# 26372                 307-778-4339       YES
# 26373                 307-778-4339       YES
# 26374                 307-766-4805       YES
# 26375                 307-766-4805       YES
# 26376                 307-766-4805       YES
# 26377                 307-766-4805       YES
# 26378                 307-766-4805       YES
# 26379                 307-766-4805       YES
#
# [26379 rows x 17 columns]

# %%
np.shape
# Out:
# (26380, 18)

# %%
np2=np
np2 = np2.dropna(subset=['Skills'])

# %%
np2.shape
# Out:
# (24416, 18)

# %%
# Import label encoder 
from sklearn import preprocessing 
  
# label_encoder object knows how to understand word labels. 
label_encoder = preprocessing.LabelEncoder()
# Encode labels in column 'species'. 
np2.Skills= label_encoder.fit_transform(np2.Skills) 
  
np2.Skills.unique()
# Out:
# C:\Users\vidhi\anaconda3\lib\site-packages\pandas\core\generic.py:5303: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[name] = value
# array([2957, 2375, 2046, ...,  507,  379,  403])

# %%
import seaborn as sns
import matplotlib.pyplot as plt
sns.set(style="darkgrid")
plt.figure(figsize=(20,13))
ax = sns.countplot(x="Skills", data=np2)

# %%
np2.Skills.replace({"Basics and Fundamentals" :"Fundamentals and Basics",
                    "Basic Fundamentals": "Fundamentals and Basics", 
                    "Basics and Fundamentals of the Game":"Fundamentals and Basics",
                    "Fundamentals and Basics with daily activities and life lessons":"Fundamentals and Basics",
                    "Basic & Fundamentals":"Fundamentals and Basics",
                    "Fundamentals":"Fundamentals and Basics",
                    "Build Teamwork, Intermediate Skills, Basic Fundamentals and Love of the Sport":"Fundamentals and Basics",
                    "Basic and Fundamentals":"Fundamentals and Basics",
                    "Fundamentals Basics and Fun!":"Fundamentals and Basics",
                    "Learn basics and fundamentals of the game":"Fundamentals and Basics",
                    "Fundamentals and Basic Skills":"Fundamentals and Basics",
                    "Introduction to the Basic Fundamentals of the Game":"Fundamentals and Basics",
                    "All players will be taught the fundamental skills of the game along with basic team shape":"Fundamentals and Basics",
                    "All players will be taught the fundamental skills of the game along with basic team shape":"Fundamentals and Basics",
                    "Emphasis on fundamentals":"Fundamentals and Basics",
                    "Introduce the basic fundamentals of the game":"Fundamentals and Basics",
                    "Individuals at our camps will work on fundamentals in game-like settings, while in a fun and enjoyable setting":"Fundamentals and Basics" })
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-22-ac2bcc1c0fc1> in <module>
#      15                     "Emphasis on fundamentals":"Fundamentals and Basics",
#      16                     "Introduce the basic fundamentals of the game":"Fundamentals and Basics",
# ---> 17                     "Individuals at our camps will work on fundamentals in game-like settings, while in a fun and enjoyable setting":"Fundamentals and Basics" })
#
# ~\anaconda3\lib\site-packages\pandas\core\series.py in replace(self, to_replace, value, inplace, limit, regex, method)
#    4176             limit=limit,
#    4177             regex=regex,
# -> 4178             method=method,
#    4179         )
#    4180
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in replace(self, to_replace, value, inplace, limit, regex, method)
#    6644
#    6645             return self.replace(
# -> 6646                 to_replace, value, inplace=inplace, limit=limit, regex=regex
#    6647             )
#    6648         else:
#
# ~\anaconda3\lib\site-packages\pandas\core\series.py in replace(self, to_replace, value, inplace, limit, regex, method)
#    4176             limit=limit,
#    4177             regex=regex,
# -> 4178             method=method,
#    4179         )
#    4180
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in replace(self, to_replace, value, inplace, limit, regex, method)
#    6697                         dest_list=value,
#    6698                         inplace=inplace,
# -> 6699                         regex=regex,
#    6700                     )
#    6701
#
# ~\anaconda3\lib\site-packages\pandas\core\internals\managers.py in replace_list(self, src_list, dest_list, inplace, regex)
#     611             return _compare_or_regex_search(values, s, regex)
#     612
# --> 613         masks = [comp(s, regex) for i, s in enumerate(src_list)]
#     614
#     615         result_blocks = []
#
# ~\anaconda3\lib\site-packages\pandas\core\internals\managers.py in <listcomp>(.0)
#     611             return _compare_or_regex_search(values, s, regex)
#     612
# --> 613         masks = [comp(s, regex) for i, s in enumerate(src_list)]
#     614
#     615         result_blocks = []
#
# ~\anaconda3\lib\site-packages\pandas\core\internals\managers.py in comp(s, regex)
#     609                     maybe_convert_objects(values), s.asm8, regex
#     610                 )
# --> 611             return _compare_or_regex_search(values, s, regex)
#     612
#     613         masks = [comp(s, regex) for i, s in enumerate(src_list)]
#
# ~\anaconda3\lib\site-packages\pandas\core\internals\managers.py in _compare_or_regex_search(a, b, regex)
#    1934
#    1935         raise TypeError(
# -> 1936             f"Cannot compare types {repr(type_names[0])} and {repr(type_names[1])}"
#    1937         )
#    1938     return result
#
# TypeError: Cannot compare types 'ndarray(dtype=int32)' and 'str'

# %%
np2
# Out:
#                                         Sports Camp Name Sports Offered  \
# 0           Alabama A&M University 2016 Fundamental Camp       Baseball
# 1      Alabama A&M University 2016 Summer Skills Clin...       Baseball
# 2      Alabama A&M University 2016 Summer Skills Clin...       Baseball
# 3      Alabama A&M University 2016 Summer Skills Clin...       Baseball
# 4                   Alabama A&M University Showcase Camp       Baseball
# ...                                                  ...            ...
# 26375  University of Wyoming - Volleyball Elite Camp ...     Volleyball
# 26376  University of Wyoming - Volleyball Skills Camp...     Volleyball
# 26377  University of Wyoming - Volleyball Skills Camp...     Volleyball
# 26378  University of Wyoming - Volleyball Team Camp (...     Volleyball
# 26379  University of Wyoming - Volleyball Team Camp (...     Volleyball
#
#        Skills                             Required Skill Level Gender  \
# 0        2957  Novice, Beginner, Intermediate, Advanced, Elite      B
# 1        2375                                     Intermediate      B
# 2        2375                                     Intermediate      B
# 3        2375                                     Intermediate      B
# 4        2957  Novice, Beginner, Intermediate, Advanced, Elite      B
# ...       ...                                              ...    ...
# 26375     507                           Intermediate, Advanced      F
# 26376     379                           Beginner, Intermediate      F
# 26377     379                           Beginner, Intermediate      F
# 26378     403                           Intermediate, Advanced      F
# 26379     403                           Intermediate, Advanced      F
#
#                  Age              Schedule Asssociated Organization  \
# 0          Ages 7-14             Half Week   Alabama A&M University
# 1      not available              Full Day   Alabama A&M University
# 2      not available              Full Day   Alabama A&M University
# 3      not available              Full Day   Alabama A&M University
# 4      not available             Half Week   Alabama A&M University
# ...              ...                   ...                      ...
# 26375      Ages 0-99  Overnight, Half Week    University of Wyoming
# 26376      Ages 0-99   Full Day, Half Week    University of Wyoming
# 26377      Ages 0-99  Overnight, Half Week    University of Wyoming
# 26378      Ages 0-99   Full Day, Half Week    University of Wyoming
# 26379      Ages 0-99  Overnight, Half Week    University of Wyoming
#
#              City State Region Capacity        Price Contact Person  \
# 0      Hunstville    AL     SE    1-100         $105     Mitch Mill
# 1      Hunstville    AL     SE    1-100  $100 - $195     Mitch Mill
# 2      Hunstville    AL     SE    1-100  $100 - $195     Mitch Mill
# 3      Hunstville    AL     SE    1-100  $100 - $195     Mitch Mill
# 4      Hunstville    AL     SE    1-100          $80     Mitch Mill
# ...           ...   ...    ...      ...          ...            ...
# 26375     Laramie    WY     NW    1-100          260  Kindra Gillen
# 26376     Laramie    WY     NW    1-100    $235-$275  Kindra Gillen
# 26377     Laramie    WY     NW    1-100          365  Kindra Gillen
# 26378     Laramie    WY     NW    1-100    $235-$275  Kindra Gillen
# 26379     Laramie    WY     NW    1-100          365  Kindra Gillen
#
#               Position of Contact Person Camp Email Address    Phone Number  \
# 0                             Head Coach      info@aamu.edu  (256) 372-5000
# 1                             Head Coach      info@aamu.edu  (256) 372-5000
# 2                             Head Coach      info@aamu.edu  (256) 372-5000
# 3                             Head Coach      info@aamu.edu  (256) 372-5000
# 4                             Head Coach      info@aamu.edu  (256) 372-5000
# ...                                  ...                ...             ...
# 26375  Camp Coordinator, Assistant Coach   kgillen@uwyo.edu    307-766-4805
# 26376  Camp Coordinator, Assistant Coach   kgillen@uwyo.edu    307-766-4805
# 26377  Camp Coordinator, Assistant Coach   kgillen@uwyo.edu    307-766-4805
# 26378  Camp Coordinator, Assistant Coach   kgillen@uwyo.edu    307-766-4805
# 26379  Camp Coordinator, Assistant Coach   kgillen@uwyo.edu    307-766-4805
#
#       Complete?
# 0           YES
# 1           YES
# 2           YES
# 3           YES
# 4           YES
# ...         ...
# 26375       YES
# 26376       YES
# 26377       YES
# 26378       YES
# 26379       YES
#
# [24416 rows x 18 columns]

# %%
np2.Skills.nunique()
# Out:
# 3053

# %%
np3=np
np3 = np3.dropna(subset=['Required Skill Level'])

# %%
np3['Required Skill Level'].replace({"Advance" : "Advanced",
                    "Advanced Beginner": "Advanced", 
                    "Advance, Elite": "Advanced, Elite",
                    "Advanced to Elite": "Advanced, Elite",
                    "Advanced and Tournament Intermediate": "Intermediate, Advanced",
                    "Advanced Intermediate": "Intermediate, Advanced",
                    "Intermediate  to Advanced": "Intermediate, Advanced",
                    "Advanced Beginner, Intermediate": "Beginner, Intermediate, Advanced",   
                    "Beginner , Intermediate, Advanced": "Beginner, Intermediate, Advanced",
                    "Beginner, Intermediate,  Advanced": "Beginner, Intermediate, Advanced",
                    "Beginner, Intermediate, Advanced Beginner": "Beginner, Intermediate, Advanced",
                    "Advanced and Tournament Intermediate": "Intermediate, Advanced",
                    "Advanced Intermediate": "Intermediate, Advanced",
                    "Intermediate  to Advanced": "Intermediate, Advanced",
                    "Beginer": "Beginner",
                    "Beginner, Intermedaite, Advanced, Elite": "Beginner, Intermediate, Advanced, Elite",
                    "Beginner, Intermediate, Advanced Elite": "Beginner, Intermediate, Advanced, Elite",
                    "Novice, Beginner, Intermediate,": "Novice, Beginner, Intermediate",
                    "Novice,Beginner, Intermediate": "Novice, Beginner, Intermediate",
                    "Novice, Beginner, Intermediate, Advanced and Elite": "Novice, Beginner, Intermediate, Advanced, Elite",
                    "Novice, Beginner, Intermediate, Advanced Elite": "Novice, Beginner, Intermediate, Advanced, Elite"                 
                   })
# Out:
# 0        Novice, Beginner, Intermediate, Advanced, Elite
# 1                                           Intermediate
# 2                                           Intermediate
# 3                                           Intermediate
# 4        Novice, Beginner, Intermediate, Advanced, Elite
#                               ...
# 26375                             Intermediate, Advanced
# 26376                             Beginner, Intermediate
# 26377                             Beginner, Intermediate
# 26378                             Intermediate, Advanced
# 26379                             Intermediate, Advanced
# Name: Required Skill Level, Length: 24314, dtype: object

# %%
np3['Required Skill Level'].nunique()
# Out:
# 43

# %%
np3['Required Skill Level'].unique()
# Out:
# array(['Novice, Beginner, Intermediate, Advanced, Elite', 'Intermediate',
#        'Others', 'Advanced', 'Elite', 'Beginner',
#        'Beginner, Intermediate', 'Intermediate, Advanced',
#        'Beginner, Intermediate, Advanced', 'Novice, Beginner',
#        'Beginner, Intermediate, Advanced, Elite',
#        'Intermediate, Advanced, Elite', 'Advanced, Elite', 'Advance',
#        'Novice, Beginner, Intermediate, Advanced',
#        'Novice, Beginner, Intermediate, Advanced Elite', ' Elite',
#        'Beginner, Intermediate, Advanced Elite', 'Novice',
#        'Novice, Beginner, Intermediate, Advanced and Elite',
#        'Beginner , Intermediate, Advanced',
#        'Novice, Beginner, Intermediate,',
#        'Novice, Beginner, Intermediate',
#        'Advanced and Tournament Intermediate',
#        'Beginner, Intermediate Player', 'Advanced Beginner',
#        'Advanced Beginner, Intermediate',
#        'Beginner, Intermediate, Advanced Beginner',
#        'Advanced Intermediate', 'intermediate', 'advanced',
#        'Advanced to Elite', 'Intermediate  to Advanced', 'Beginer',
#        'Novice,Beginner, Intermediate',
#        'Beginner, Intermediate,  Advanced', ' Beginner',
#        'In addition to learning from Coach Frank Martin and his coaching staff, participants will interact with the South Carolina basketball players and take part in behind the scenes tours of our facilities, to include the newly renovated Game Day Locker Room at the Colonial Life Arena',
#        'Beginner ', ' Intermediate, Advanced',
#        'Beginner, Intermedaite, Advanced, Elite',
#        'Beginner, intermediate', 'Advance, Elite'], dtype=object)

# %%
np3 = np3[~np3["Required Skill Level"].str.contains("In addition to learning from Coach Frank Martin and his coaching staff, participants will interact with the South Carolina basketball players and take part in behind the scenes tours of our facilities, to include the newly renovated Game Day Locker Room at the Colonial Life Arena")]

# %%
np3['Required Skill Level'].unique()
# Out:
# array(['Novice, Beginner, Intermediate, Advanced, Elite', 'Intermediate',
#        'Others', 'Advanced', 'Elite', 'Beginner',
#        'Beginner, Intermediate', 'Intermediate, Advanced',
#        'Beginner, Intermediate, Advanced', 'Novice, Beginner',
#        'Beginner, Intermediate, Advanced, Elite',
#        'Intermediate, Advanced, Elite', 'Advanced, Elite', 'Advance',
#        'Novice, Beginner, Intermediate, Advanced',
#        'Novice, Beginner, Intermediate, Advanced Elite', ' Elite',
#        'Beginner, Intermediate, Advanced Elite', 'Novice',
#        'Novice, Beginner, Intermediate, Advanced and Elite',
#        'Beginner , Intermediate, Advanced',
#        'Novice, Beginner, Intermediate,',
#        'Novice, Beginner, Intermediate',
#        'Advanced and Tournament Intermediate',
#        'Beginner, Intermediate Player', 'Advanced Beginner',
#        'Advanced Beginner, Intermediate',
#        'Beginner, Intermediate, Advanced Beginner',
#        'Advanced Intermediate', 'intermediate', 'advanced',
#        'Advanced to Elite', 'Intermediate  to Advanced', 'Beginer',
#        'Novice,Beginner, Intermediate',
#        'Beginner, Intermediate,  Advanced', ' Beginner',
#        'In addition to learning from Coach Frank Martin and his coaching staff, participants will interact with the South Carolina basketball players and take part in behind the scenes tours of our facilities, to include the newly renovated Game Day Locker Room at the Colonial Life Arena',
#        'Beginner ', ' Intermediate, Advanced',
#        'Beginner, Intermedaite, Advanced, Elite',
#        'Beginner, intermediate', 'Advance, Elite'], dtype=object)

# %%
import seaborn as sns
import matplotlib.pyplot as plt
sns.set(style="darkgrid")
plt.figure(figsize=(40,30))
ax = sns.countplot(y="Required Skill Level", data=np3)

# %%
import seaborn as sns
import matplotlib.pyplot as plt
sns.set(style="darkgrid")
plt.figure(figsize=(8,6))
ax = sns.countplot(x="Gender", data=np1)

# %%
np4=np
np4 = np4.dropna(subset=['Schedule'])

# %%
np4.Schedule = np4.Schedule.replace('\n','', regex=True)
# Out:
# C:\Users\vidhi\anaconda3\lib\site-packages\pandas\core\generic.py:5303: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[name] = value

# %% [markdown]
# "Other":"Others",
#                      "not available":"Others",
#                      "N/A":"Others",
#                      "Full Day, Others":"Others",
#                      "Full Day, Overnight":"Others",
#                      "Half Week, Full Week":"Others",
#                      "June 12 - 16, 2017":"Others",
#                      "June 26 - 30, 2017":"Others",
#                      "June 19 - 22, 2017":"Others",
#                      "June 19 - 23, 2017":"Others",
#                      "June 26 - 29, 2017":"Others",
#                      "June 5 - 9, 2017":"Others",
#                      "TBA":"Others",
#                      "7 Jul 2017 until 10 Jul 2017 12:00 PM - 12:00 PM":"Others",
#                      "Full Day, Overnight, Half Week":"Others",
#                      "Half Day, Overnight":"Others",
#                      "Half Day, Overnight, Half Week":"Others",
#                      "Jun 14, 20171pm-4pm":"Others",
#                      "Jun 14, 20179am-12pm":"Others",
#                      "Jun 1610:30am-11:45am":"Others",
#                      "Jun 161:30pm-2:45pm":"Others",
#                      "Jun 169am-10:15am":"Others",
#                      "Jun 210:30am-11:45am":"Others",
#                      "Jun 212pm-1:15pm":"Others",
#                      "Jun 21:30pm-2:45pm":"Others",
#                      "Jun 29am-10:15am":"Others",
#                      "Jun 2310:30am-11:45am":"Others",
#                      "Jun 2312pm-1:15pm":"Others",
#                      "Jun 231:30pm-2:45pm":"Others",
#                      "Jun 239am-10:15am":"Others",
#                      "Jun 26, 201612pm-3pm":"Others",
#                      "Jun 26, 20163:30pm-6:30pm":"Others",
#                      "Jun 910:30am-11:45am":"Others",
#                      "Jun 912pm-1:15pm":"Others",
#                      "Jun 91:30pm-2:45pm":"Others",
#                      "Jun 99am-10:15am":"Others",
#                      "June 15":"Others",
#                      "June 18 - 20, 2013":"Others",
#                      "June 19 - 21 and 23, 2017":"Others",
#                      "June 19 - 21, 2017":"Others",
#                      "June 26 -29, 2017":"Others",
#                      "June 27 - 29, 2017":"Others",
#                      "June 5-9, 2017":"Others",
#                      "Nov 9 - Dec 2, 20167 seperate sessions over a 4 week period":"Others",
#                      "Sep 39am-4pm":"Others",
#                      "Sep 49am-4pm":"Others",
#                      "Sun, July 09, 2017 to Thu, July 13, 2017":"Others",
#                      "TBD":"Others"

# %%
np3=df

# %%
np3['Schedule'].replace({"Half Day;Half Week" : "Half Day, Half Week",
                    "Half Week, Half Day": "Half Day, Half Week", 
                    "Half Week;Half Day": "Half Day, Half Week",
                    "Halfday, Half Week": "Half Day, Half Week",
                    "Full Week, Half Day": "Half Day, Full Week",
                    "Half Day;Full Week": "Half Day, Full Week",
                    "Half Day; Full Week": "Half Day, Full Week",
                    "Full Week, Full Day": "Full Day, Full Week",
                    "Full Day;Full Week": "Full Day, Full Week",
                    "Half Week, Full Day": "Full Day, Half Week",   
                    "Half Week, Overnight": "Overnight, Half Week",
                    "Overight, Half Week": "Overnight, Half Week",
                    "Full Week, Overnight": "Overnight, Full Week",
                   })
# Out:
# 0                   Half Week
# 1                    Full Day
# 2                    Full Day
# 3                    Full Day
# 4                   Half Week
#                  ...
# 26375    Overnight, Half Week
# 26376     Full Day, Half Week
# 26377    Overnight, Half Week
# 26378     Full Day, Half Week
# 26379    Overnight, Half Week
# Name: Schedule, Length: 26380, dtype: object

# %%
np3.Schedule.nunique()
# Out:
# 82

# %%
np3['Schedule'].unique()
# Out:
# array(['Half Week', 'Full Day', 'Others', 'Full Week', 'not available',
#        nan, 'Full Week, Half Day', 'Full Week, Full Day', 'Half Day',
#        'Half Week, Full Day', 'Half Day, Half Week', 'Overnight',
#        'Overnight, Half Week', 'Full Day, Half Week',
#        'Full Day, Full Week', 'Half Day, Full Week',
#        'Overnight, Full Week', 'TBA', 'TBD', 'Halfday, Half Week',
#        'Half Week, Full Week', ' Full Day', 'Full day', 'overnight',
#        'Full Day, Overnight', 'Full Week, Overnight', 'Other',
#        'Full Day ', 'Full Day, full Week', 'Half Week, Overnight',
#        'Half Week, Half Day', 'Half Day;Half Week', 'Half Day;Full Week',
#        'Full Day;Full Week', 'Half Day; Full Week', 'Half Week;Half Day',
#        'Jun 26, 2016\n12pm-3pm', 'Jun 26, 2016\n3:30pm-6:30pm',
#        'Jun 2\n9am-10:15am', 'Jun 9\n9am-10:15am', 'Jun 16\n9am-10:15am',
#        'Jun 23\n9am-10:15am', 'Jun 2\n10:30am-11:45am',
#        'Jun 9\n10:30am-11:45am', 'Jun 16\n10:30am-11:45am',
#        'Jun 23\n10:30am-11:45am', 'Jun 2\n12pm-1:15pm',
#        'Jun 9\n12pm-1:15pm', 'Jun 16\n12pm-1:15pm', 'Jun 23\n12pm-1:15pm',
#        'Jun 2\n1:30pm-2:45pm', 'Jun 9\n1:30pm-2:45pm',
#        'Jun 16\n1:30pm-2:45pm', 'Jun 23\n1:30pm-2:45pm',
#        'Nov 9 - Dec 2, 2016\n7 seperate sessions over a 4 week period',
#        'Jun 14, 2017\n9am-12pm', 'Sep 3\n9am-4pm', 'Sep 4\n9am-4pm',
#        'Jun 14, 2017\n1pm-4pm',
#        'Sun, July 09, 2017 to Thu, July 13, 2017',
#        '7 Jul 2017 until 10 Jul 2017 12:00 PM - 12:00 PM',
#        'June 26 - 30, 2017', 'June 19 - 23, 2017', 'June 19 - 22, 2017',
#        'June 26 - 29, 2017', 'June 26 -29, 2017', 'June 5 - 9, 2017',
#        'June 15', 'Not Available', 'Half Day ', 'June 12 - 16, 2017',
#        'June 27 - 29, 2017', 'Full Day, Others', 'Ful Day, Half Week',
#        'June 5-9, 2017', 'June 19 - 21 and 23, 2017',
#        'June 19 - 21, 2017', 'June 18 - 20, 2013',
#        'Full Day, Overnight, Half Week', 'Half Day, Overnight, Half Week',
#        'Half Day, Overnight', 'Overight, Half Week', 'Half day'],
#       dtype=object)

# %%
np3 = np3[~np3["Required Skill Level"].str.contains("In addition to learning from Coach Frank Martin and his coaching staff, participants will interact with the South Carolina basketball players and take part in behind the scenes tours of our facilities, to include the newly renovated Game Day Locker Room at the Colonial Life Arena")]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-42-175ad51444b4> in <module>
# ----> 1 np3 = np3[~np3["Required Skill Level"].str.contains("In addition to learning from Coach Frank Martin and his coaching staff, participants will interact with the South Carolina basketball players and take part in behind the scenes tours of our facilities, to include the newly renovated Game Day Locker Room at the Colonial Life Arena")]
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in __invert__(self)
#    1471             return self
#    1472
# -> 1473         new_data = self._data.apply(operator.invert)
#    1474         result = self._constructor(new_data).__finalize__(self)
#    1475         return result
#
# ~\anaconda3\lib\site-packages\pandas\core\internals\managers.py in apply(self, f, filter, **kwargs)
#     438
#     439             if callable(f):
# --> 440                 applied = b.apply(f, **kwargs)
#     441             else:
#     442                 applied = getattr(b, f)(**kwargs)
#
# ~\anaconda3\lib\site-packages\pandas\core\internals\blocks.py in apply(self, func, **kwargs)
#     388         """
#     389         with np.errstate(all="ignore"):
# --> 390             result = func(self.values, **kwargs)
#     391
#     392         if is_extension_array_dtype(result) and result.ndim > 1:
#
# TypeError: bad operand type for unary ~: 'float'

# %%
np3['Region'].nunique()
# Out:
# 7

# %%
np4 = np

# %%
np4
# Out:
#                                         Sports Camp Name Sports Offered  \
# 0           Alabama A&M University 2016 Fundamental Camp       Baseball
# 1      Alabama A&M University 2016 Summer Skills Clin...       Baseball
# 2      Alabama A&M University 2016 Summer Skills Clin...       Baseball
# 3      Alabama A&M University 2016 Summer Skills Clin...       Baseball
# 4                   Alabama A&M University Showcase Camp       Baseball
# ...                                                  ...            ...
# 26375  University of Wyoming - Volleyball Elite Camp ...     Volleyball
# 26376  University of Wyoming - Volleyball Skills Camp...     Volleyball
# 26377  University of Wyoming - Volleyball Skills Camp...     Volleyball
# 26378  University of Wyoming - Volleyball Team Camp (...     Volleyball
# 26379  University of Wyoming - Volleyball Team Camp (...     Volleyball
#
#                                                   Skills  \
# 0                                             all skills
# 1      Techniques, drills and skill specific exercise...
# 2      Techniques, drills and skill specific exercise...
# 3      Techniques, drills and skill specific exercise...
# 4                                             all skills
# ...                                                  ...
# 26375  Camp will involve more advanced skill instruct...
# 26376  Camp are designed for the beginner to intermed...
# 26377  Camp are designed for the beginner to intermed...
# 26378  Camp is a great opportunity for Middle & High ...
# 26379  Camp is a great opportunity for Middle & High ...
#
#                                   Required Skill Level Gender            Age  \
# 0      Novice, Beginner, Intermediate, Advanced, Elite      B      Ages 7-14
# 1                                         Intermediate      B  not available
# 2                                         Intermediate      B  not available
# 3                                         Intermediate      B  not available
# 4      Novice, Beginner, Intermediate, Advanced, Elite      B  not available
# ...                                                ...    ...            ...
# 26375                           Intermediate, Advanced      F      Ages 0-99
# 26376                           Beginner, Intermediate      F      Ages 0-99
# 26377                           Beginner, Intermediate      F      Ages 0-99
# 26378                           Intermediate, Advanced      F      Ages 0-99
# 26379                           Intermediate, Advanced      F      Ages 0-99
#
#                    Schedule Asssociated Organization        City State Region  \
# 0                 Half Week   Alabama A&M University  Hunstville    AL     SE
# 1                  Full Day   Alabama A&M University  Hunstville    AL     SE
# 2                  Full Day   Alabama A&M University  Hunstville    AL     SE
# 3                  Full Day   Alabama A&M University  Hunstville    AL     SE
# 4                 Half Week   Alabama A&M University  Hunstville    AL     SE
# ...                     ...                      ...         ...   ...    ...
# 26375  Overnight, Half Week    University of Wyoming     Laramie    WY     NW
# 26376   Full Day, Half Week    University of Wyoming     Laramie    WY     NW
# 26377  Overnight, Half Week    University of Wyoming     Laramie    WY     NW
# 26378   Full Day, Half Week    University of Wyoming     Laramie    WY     NW
# 26379  Overnight, Half Week    University of Wyoming     Laramie    WY     NW
#
#       Capacity        Price Contact Person         Position of Contact Person  \
# 0        1-100         $105     Mitch Mill                         Head Coach
# 1        1-100  $100 - $195     Mitch Mill                         Head Coach
# 2        1-100  $100 - $195     Mitch Mill                         Head Coach
# 3        1-100  $100 - $195     Mitch Mill                         Head Coach
# 4        1-100          $80     Mitch Mill                         Head Coach
# ...        ...          ...            ...                                ...
# 26375    1-100          260  Kindra Gillen  Camp Coordinator, Assistant Coach
# 26376    1-100    $235-$275  Kindra Gillen  Camp Coordinator, Assistant Coach
# 26377    1-100          365  Kindra Gillen  Camp Coordinator, Assistant Coach
# 26378    1-100    $235-$275  Kindra Gillen  Camp Coordinator, Assistant Coach
# 26379    1-100          365  Kindra Gillen  Camp Coordinator, Assistant Coach
#
#       Camp Email Address    Phone Number Complete?
# 0          info@aamu.edu  (256) 372-5000       YES
# 1          info@aamu.edu  (256) 372-5000       YES
# 2          info@aamu.edu  (256) 372-5000       YES
# 3          info@aamu.edu  (256) 372-5000       YES
# 4          info@aamu.edu  (256) 372-5000       YES
# ...                  ...             ...       ...
# 26375   kgillen@uwyo.edu    307-766-4805       YES
# 26376   kgillen@uwyo.edu    307-766-4805       YES
# 26377   kgillen@uwyo.edu    307-766-4805       YES
# 26378   kgillen@uwyo.edu    307-766-4805       YES
# 26379   kgillen@uwyo.edu    307-766-4805       YES
#
# [26380 rows x 18 columns]

# %%
import numpy
np4['Capacity']= np4['Capacity'].replace(numpy.nan, 0)
# Out:
# C:\Users\vidhi\anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
import numpy
np4['Price']= np4['Price'].replace(numpy.nan, 0)
# Out:
# C:\Users\vidhi\anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
np4
# Out:
#                                         Sports Camp Name Sports Offered  \
# 0           Alabama A&M University 2016 Fundamental Camp       Baseball
# 1      Alabama A&M University 2016 Summer Skills Clin...       Baseball
# 2      Alabama A&M University 2016 Summer Skills Clin...       Baseball
# 3      Alabama A&M University 2016 Summer Skills Clin...       Baseball
# 4                   Alabama A&M University Showcase Camp       Baseball
# ...                                                  ...            ...
# 26375  University of Wyoming - Volleyball Elite Camp ...     Volleyball
# 26376  University of Wyoming - Volleyball Skills Camp...     Volleyball
# 26377  University of Wyoming - Volleyball Skills Camp...     Volleyball
# 26378  University of Wyoming - Volleyball Team Camp (...     Volleyball
# 26379  University of Wyoming - Volleyball Team Camp (...     Volleyball
#
#                                                   Skills  \
# 0                                             all skills
# 1      Techniques, drills and skill specific exercise...
# 2      Techniques, drills and skill specific exercise...
# 3      Techniques, drills and skill specific exercise...
# 4                                             all skills
# ...                                                  ...
# 26375  Camp will involve more advanced skill instruct...
# 26376  Camp are designed for the beginner to intermed...
# 26377  Camp are designed for the beginner to intermed...
# 26378  Camp is a great opportunity for Middle & High ...
# 26379  Camp is a great opportunity for Middle & High ...
#
#                                   Required Skill Level Gender            Age  \
# 0      Novice, Beginner, Intermediate, Advanced, Elite      B      Ages 7-14
# 1                                         Intermediate      B  not available
# 2                                         Intermediate      B  not available
# 3                                         Intermediate      B  not available
# 4      Novice, Beginner, Intermediate, Advanced, Elite      B  not available
# ...                                                ...    ...            ...
# 26375                           Intermediate, Advanced      F      Ages 0-99
# 26376                           Beginner, Intermediate      F      Ages 0-99
# 26377                           Beginner, Intermediate      F      Ages 0-99
# 26378                           Intermediate, Advanced      F      Ages 0-99
# 26379                           Intermediate, Advanced      F      Ages 0-99
#
#                    Schedule Asssociated Organization        City State Region  \
# 0                 Half Week   Alabama A&M University  Hunstville    AL     SE
# 1                  Full Day   Alabama A&M University  Hunstville    AL     SE
# 2                  Full Day   Alabama A&M University  Hunstville    AL     SE
# 3                  Full Day   Alabama A&M University  Hunstville    AL     SE
# 4                 Half Week   Alabama A&M University  Hunstville    AL     SE
# ...                     ...                      ...         ...   ...    ...
# 26375  Overnight, Half Week    University of Wyoming     Laramie    WY     NW
# 26376   Full Day, Half Week    University of Wyoming     Laramie    WY     NW
# 26377  Overnight, Half Week    University of Wyoming     Laramie    WY     NW
# 26378   Full Day, Half Week    University of Wyoming     Laramie    WY     NW
# 26379  Overnight, Half Week    University of Wyoming     Laramie    WY     NW
#
#       Capacity        Price Contact Person         Position of Contact Person  \
# 0        1-100         $105     Mitch Mill                         Head Coach
# 1        1-100  $100 - $195     Mitch Mill                         Head Coach
# 2        1-100  $100 - $195     Mitch Mill                         Head Coach
# 3        1-100  $100 - $195     Mitch Mill                         Head Coach
# 4        1-100          $80     Mitch Mill                         Head Coach
# ...        ...          ...            ...                                ...
# 26375    1-100          260  Kindra Gillen  Camp Coordinator, Assistant Coach
# 26376    1-100    $235-$275  Kindra Gillen  Camp Coordinator, Assistant Coach
# 26377    1-100          365  Kindra Gillen  Camp Coordinator, Assistant Coach
# 26378    1-100    $235-$275  Kindra Gillen  Camp Coordinator, Assistant Coach
# 26379    1-100          365  Kindra Gillen  Camp Coordinator, Assistant Coach
#
#       Camp Email Address    Phone Number Complete?
# 0          info@aamu.edu  (256) 372-5000       YES
# 1          info@aamu.edu  (256) 372-5000       YES
# 2          info@aamu.edu  (256) 372-5000       YES
# 3          info@aamu.edu  (256) 372-5000       YES
# 4          info@aamu.edu  (256) 372-5000       YES
# ...                  ...             ...       ...
# 26375   kgillen@uwyo.edu    307-766-4805       YES
# 26376   kgillen@uwyo.edu    307-766-4805       YES
# 26377   kgillen@uwyo.edu    307-766-4805       YES
# 26378   kgillen@uwyo.edu    307-766-4805       YES
# 26379   kgillen@uwyo.edu    307-766-4805       YES
#
# [26380 rows x 18 columns]

# %%
#start of data visulaizations

# %%
import seaborn as sns
import matplotlib.pyplot as plt
sns.set(style="darkgrid")
plt.figure(figsize=(20,20))
ax = sns.countplot(y="State", data=np4)

# %%
import seaborn as sns
import matplotlib.pyplot as plt
sns.set(style="darkgrid")
plt.figure(figsize=(6,6))
ax = sns.countplot(y="Region", data=np4)

# %%
import seaborn as sns
plt.figure(figsize=(20,20))
sns.countplot(y='Sports Offered',data=np4,hue='Gender')

# %%
import seaborn as sns
plt.figure(figsize=(20,20))
sns.countplot(y='State',data=np4,hue='Sports Offered')

# %%
import seaborn as sns
plt.figure(figsize=(20,20))
sns.countplot(y='Sports Offered',data=np4,hue='Region')

# %%
import seaborn as sns
plt.figure(figsize=(8,8))
sns.countplot(x='Gender',data=np4,hue='Region')

# %%
import seaborn as sns
plt.figure(figsize=(15,15))
sns.countplot(y='State',data=np4,hue='Gender')

# %%
temp1 = np4[(np4["State"] == "NJ")]
import seaborn as sns
plt.figure(figsize=(20,20))
sns.countplot(y='City',data=temp1,hue='Sports Offered')

# %%
import seaborn as sns
plt.figure(figsize=(15,15))
sns.countplot(y='Schedule',data=np4,hue='Sports Offered')

# %%
# Making proper groups for age

# %%
np4.Age.nunique()
# Out:
# 781

# %%
np4["Age"].unique()
# Out:
# array(['Ages 7-14', 'not available', 'ages 14-18', 'ages 6-12',
#        'Ages 6-17', 'ages 9-12', 'ages 5-11', 'ages 8-18',
#        'ages 11 and below', 'age 18', 'ages 10-18', 'ages 5 and up',
#        'All ages', 'ages 7 and up', 'ages 9 and up', 'ages 6-11',
#        'ages 7-18', 'ages 12-18', 'ages 5-18', 'ages 5-12', 'ages 3-6',
#        'ages 3-12', 'ages 8-15', 'Ages 8-12', nan, 'Ages 5-12',
#        'Ages 14-18', 'All Ages', 'Ages 8-18', 'Ages 12-19', 'Ages 9-11',
#        'Ages 8-16', 'Ages 10-18', 'Ages 14 and up', 'Ages 15 and up',
#        'Ages 7-11', 'Ages 12 and up', 'Ages 3-6', 'Ages 4-6', 'Ages 6-18',
#        'ages 16-19', 'Ages 9-18', 'Ages 10 and below', 'Ages 10-17',
#        'Ages 6-10', 'Ages 13-19', 'Age 7-10', 'Age 11 and up',
#        'Ages 14 to 18', 'Ages 9-10', 'Ages 11 and up', 'Ages 6 and up',
#        'Ages 4-13', 'Ages 11-19', 'Ages 11-14', 'Ages 6-12', 'Ages 6-13',
#        'Ages 0-99', 'Ages 7-16', 'Ages 6-11', 'Ages 12-17', 'Ages 6-14',
#        'Age 6 - 14', 'Ages 7-18', 'Ages 5-10', 'Ages 15-19', 'Ages 4-9',
#        'Ages 10-14', 'Ages 4-14', 'Ages 5-15', 'Ages 15-18', 'Ages 7-15',
#        'Ages 10-12', 'Ages 11-12', 'Ages 7-10', 'Ages 4-18', 'Ages 5-14',
#        'Ages 6 -14', 'Ages 8 -14', 'Ages 11-18', 'Ages 9-14',
#        'Ages 12-18', 'Ages 12-16', 'Ages 6-9', 'Ages 8-13', 'Ages 8-14',
#        'Ages 8-11', 'Ages 9-16', 'Ages 7-13', 'Ages 5-18', 'Ages 3-12',
#        'Ages 0-1', 'Ages 6-15', 'Ages 2-2', 'Ages 5-5', 'Ages 4-4',
#        'Ages 1-1', 'Ages 3-4', 'Ages 3-5', 'Ages 4-8', 'Ages 6-8',
#        'Ages 1-3', 'Ages 2-5', 'Ages 1-5', 'Ages 1-8', 'Ages 8-17',
#        'Ages 6-16', 'Ages 14-21', 'Ages 10-19', 'Ages 5-6', 'Ages 3-18',
#        'Ages 4-12', 'Ages 2-12', 'Ages 1-2', 'Ages 5-17', 'Ages 2-4',
#        'Ages 0-2', 'Ages 12-15', 'Ages 2-18', 'Ages 7-17', 'Ages 7-12',
#        'Ages 13-17', 'Ages 13-18', 'Ages 1-18', 'Ages 1-10', 'Ages 12-14',
#        'Ages 4-17', 'Ages 9-12', 'Ages 9-15', 'Ages 7-9', 'Ages 1-11',
#        'Ages 1-12', 'Ages 13-14', 'Ages 9-17 ', 'Ages 6-22', 'Ages 9-22',
#        'Ages 14-19', 'Ages 4-17 ', 'Ages 13-21', 'Ages 5-13',
#        'Ages 14-20', 'Ages 14-17', 'Ages 14 -18', 'Ages 5-8',
#        'Ages 11-18 ', 'Ages 9-17', 'Ages 8-15', 'Ages 4-7', 'Ages 2-8',
#        'Ages 10-15', 'Ages 3-13', 'Ages 13-16', 'Ages 21-25', 'Ages 5-16',
#        'Ages 3-15', 'Ages 4', 'Ages 4-11', 'Ages 3-16', 'Ages 3-10',
#        'Ages 11-17', 'Ages 9-99', 'Ages 0-9', 'Ages 6-99', 'Ages 3-99',
#        'Ages 8-99', 'Ages 13-20', 'Ages 9-13', 'Ages 14-22', 'Ages 10-13',
#        'Ages 5-11', 'Ages 5-9', 'Ages 3-8', 'Ages 3-7', 'Ages 3 - 7',
#        'Ages 8 - 11', 'Ages 7-8', 'Ags 7-13', 'Ags 8-18', 'Ags 9-18',
#        'Ags 10-18', '5 to 18', '-', 'Ages 12-20', '7 to 15', '9 to 17',
#        '11 to 18', '6 to 16', '5 to 14', '7 to 14', '3 to 10', '8 to 18',
#        '10 to 14', '3 to 17', '5 to 12', '3 to 13', '9 to 18', '7 to 16',
#        '9 to 16', '10 to 18', '7 to 18', '11 to 16',
#        datetime.datetime(2017, 8, 19, 0, 0), '6 to 17', '6 to 18',
#        '4 to 16', '5 to 17', '9 to 15', '6 to 14', '9 to 14',
#        datetime.datetime(2017, 11, 17, 0, 0), '8 to 17', '13 to 18',
#        '18 to All', '8 to 19', '8 to 15', 'Ages 7 -11', '12 to 18',
#        '14 to 18', '4 to 14', '12 to 15', '7 to 25', '14 to 19',
#        '6 to 15', 'Ages 8-19', 'Ages 11-13', 'Ages 10-16', 'Ages 8-9',
#        'Ages 6-7', 'Ages 13-15', 'Ages 5-7', 'Ages 4-5', 'Ages 4-10',
#        'Ages 3', 'Ages 10-11', 'Ages 12-13', 'Ages 8', 'Ages 11-15',
#        'Ages 8-10', 'Ages 14-30', 'Ages 10-18 ', 'Ages 8-18 ',
#        'Ages 8-14 ', 'Ages 6-7 ', 'Ages 4-5 ', 'Ages 5-7 ', 'Ages 6-16 ',
#        'Ages 6-8 ', 'Ages 3-6 ', 'Ages 2-3 ', 'Ages 18', 'Ages 15-18 ',
#        'Ages 9-18 ', 'ages 7-12', 'ages 13-18 years old', 'ages 8-14',
#        '6 or 7 years of age', 'ages 5-13', '7-13 years old',
#        '5-7 years old', 'ages 7-17', 'ages 7-10', 'ages 11-15',
#        'ages 21-23', 'ages 15-17', 'ages 13-14', 'ages 5 and older',
#        '7-12 years of age', '3 & 4 years', '5 & 6 years',
#        'Ages: 6 to 14 Years', 'Ages 6 or 7 years of age', 'ages 18+',
#        'ages 8-17', 'ages 8-11', 'ages 5-7', 'ages 12 & over',
#        'ages 16-18', 'ages 17-20', 'ages 18-21', 'ages 18-20',
#        'Ages 15-16', 'Ages 14 below', 'Ages 16-18', 'Age 10 - 18',
#        'Ages 3-17', 'Age 13-18', 'Ages 7-12\n', 'Ages 0-13', 'Ages 0-18',
#        'Ages 11-16', 'Ages 0-10', 'ages 15-18', 'Age 7', 'Age 8',
#        'Ages 11 to 12', 'Ages 13 to 14', 'Ages 15 to 18', 'Ages 4 to 6',
#        'Ages 9 to 10', 'Ages 11 and above', 'Ages 13 and above',
#        'Ages 14 and above', 'Age 5', 'Age 6', 'ages 9-10', 'ages 11-12',
#        'age 8', 'ages 11-18', 'ages 16 and up', 'Age 4', 'Age 3',
#        'Ages 14-15', 'Ages 15-17', 'Ages 9-16 ( Ages 12+ Overnight)',
#        'Ages 5 - 12', 'Ages 10 - 18', 'Ages 8 - 16', 'Ages5-8',
#        'ages 10-12', 'Age 5 - 13', 'ages 17-18', 'all ages',
#        'ages 18 and above', 'Ages 9 and above', 'Ages 12 and older',
#        'Ages 5 and above', 'Ages 1.2-3 ', 'Age 6 - 13', 'Ages 2-3',
#        'Age 4-6', 'Ages 14-16', 'Age 13', 'Ages 13 and up', 'Ages 4-15',
#        'Age 11', 'Ages 9-19', 'Ages 9-20', 'Ages 9-21', 'Ages 9-23',
#        'Ages 9-24', 'Ages 9-25', 'Ages 9-26', 'Ages 9-27', 'Ages 9-28',
#        'Ages 9-29', 'Ages 9-30', 'Ages 9-31', 'Ages 9-32', 'Ages 3 - 3.5',
#        'Ages 1.5-2', 'Ages 8 and up', 'Ages 5 and up', 'Ages 2-7',
#        'High School Ages', 'Ages 5-19', 'Ages 0-3', 'Ages 7 and up',
#        'Ages 18 and up', 'Ages 11 and below', 'Ages 13 and below',
#        'Ages 4 - 5', 'Ages 3.5-6', 'Ages 7 - 11 & 12 - 17', 'Ages 4 - 6',
#        'Ages 6-8 & 9-11', 'Ages 12 - 14 & 15 - 17', 'Ages 9-10, 11-14',
#        'Ages 5-6, 7-8', 'Ages 5 to 17', 'Ages 6 and under',
#        datetime.datetime(2017, 7, 14, 0, 0), '7u-10u', '11u-14u',
#        'ages 7-14', '9U', '10U', '11U', '12U',
#        '7U, 8U, 9U, 10U, 11U, 12U, 13U or 14U divisions',
#        datetime.datetime(2017, 7, 18, 0, 0),
#        datetime.datetime(2017, 8, 18, 0, 0), '14-18',
#        datetime.datetime(2017, 8, 17, 0, 0),
#        datetime.datetime(2017, 10, 13, 0, 0),
#        datetime.datetime(2017, 11, 18, 0, 0),
#        datetime.datetime(2017, 7, 15, 0, 0),
#        datetime.datetime(2017, 8, 13, 0, 0),
#        datetime.datetime(2017, 11, 16, 0, 0),
#        datetime.datetime(2017, 10, 18, 0, 0),
#        datetime.datetime(2017, 9, 18, 0, 0),
#        datetime.datetime(2017, 5, 13, 0, 0),
#        datetime.datetime(2017, 8, 15, 0, 0),
#        datetime.datetime(2017, 11, 13, 0, 0),
#        datetime.datetime(2017, 6, 18, 0, 0),
#        datetime.datetime(2017, 8, 14, 0, 0),
#        datetime.datetime(2017, 5, 6, 0, 0),
#        datetime.datetime(2017, 7, 8, 0, 0),
#        datetime.datetime(2017, 9, 12, 0, 0),
#        datetime.datetime(2017, 5, 12, 0, 0),
#        datetime.datetime(2017, 4, 13, 0, 0),
#        datetime.datetime(2017, 7, 13, 0, 0), '7 to 9', '7 to 13',
#        '3.5 to 12', datetime.datetime(2017, 9, 14, 0, 0),
#        datetime.datetime(2017, 6, 15, 0, 0),
#        datetime.datetime(2017, 12, 18, 0, 0),
#        datetime.datetime(2017, 4, 14, 0, 0),
#        datetime.datetime(2017, 4, 8, 0, 0),
#        datetime.datetime(2017, 3, 5, 0, 0),
#        datetime.datetime(2017, 12, 16, 0, 0), '14-23',
#        datetime.datetime(2017, 4, 16, 0, 0),
#        datetime.datetime(2017, 7, 17, 0, 0),
#        datetime.datetime(2017, 6, 12, 0, 0),
#        datetime.datetime(2017, 6, 14, 0, 0),
#        datetime.datetime(2017, 12, 17, 0, 0),
#        datetime.datetime(2017, 11, 22, 0, 0), '14-17',
#        datetime.datetime(2017, 4, 17, 0, 0),
#        datetime.datetime(2017, 3, 17, 0, 0),
#        datetime.datetime(2017, 5, 17, 0, 0),
#        datetime.datetime(2017, 8, 12, 0, 0), '6-8 Middle School',
#        datetime.datetime(2017, 7, 12, 0, 0), 'Gr. 3-12', 'Gr. 3-8',
#        datetime.datetime(2017, 9, 16, 0, 0),
#        datetime.datetime(2017, 10, 28, 0, 0),
#        datetime.datetime(2017, 8, 16, 0, 0), 'Gr 3-6',
#        datetime.datetime(2017, 2, 5, 0, 0), 'Gr 9-12', 'Gr. 6-8',
#        datetime.datetime(2017, 3, 15, 0, 0),
#        datetime.datetime(2017, 7, 16, 0, 0),
#        datetime.datetime(2017, 9, 17, 0, 0),
#        datetime.datetime(2017, 6, 17, 0, 0),
#        datetime.datetime(1965, 8, 1, 0, 0), 'Gr 1-8',
#        datetime.datetime(2017, 3, 14, 0, 0),
#        datetime.datetime(2017, 11, 14, 0, 0),
#        datetime.datetime(2017, 9, 15, 0, 0), ' Ages 6-18', 'Ages 2-10',
#        'Ages 6-12 ', 'Ages 6-14 ', 'Age 10-18', 'ages 16-17', 'Ages 1-13',
#        'ages 13-17', 'ages 11-14', ' ages 7-17', 'ages 6-9', 'ages 7-17 ',
#        'ages 5-16 ', 'Age: Incoming 9th-12th', 'Ages 18-0',
#        'Ages 7 to 14', 'Ages 4.5-6', 'Ages 4.5-7', 'Ages 6 mos',
#        'Ages 3-4.5', 'Ages 16-19', 'Ages 8 to 12', 'Ages 6 to 16',
#        'Ages 9 to 18', 'Ages 5 to 14', 'Ages 7 to 13', 'Ages 15 to 19',
#        'Ages 6 to 13', 'Ages 7 to 10', 'Ages 9 to 12', 'Ages 14 to 16',
#        'Ages 10 to 13', 'Ages 7 to 15', 'Ages 16 to 18', 'Ages 6 to 15',
#        'Ages 13 to 18', 'Ages 3 to 5', 'Ages 8 to 15', 'Ages 8 to 13',
#        'Ages 9 to 14', 'Ages 8 to 14', 'Ages 5 to 12', 'Ages 10 to 18',
#        'Ages 4 to 5', 'Ages 2 to 3', 'Ages 7 to 9', 'Ages 11 to 18',
#        'Ages 9 to 16', 'Ages 4 and up', 'Ages 2½ to 5', 'Ages 10 to 11',
#        'Ages 18 and below', 'Ages 13 to 19', 'Ages 7 to 18',
#        'Ages 14 to 19', 'Ages 16 to 19', 'Ages 5 to 19', 'Ages 8 to 9 ',
#        'Ages 16 to 21', 'Ages 10 to 19', 'Ages 6 to 18', 'Ages 6 - 13',
#        'Ages 15 - 18', 'Ages 8 - 13', 'Ages 5 - 14', 'Ages 9 - 12',
#        'Ages 13 - 19', 'Ages 5 - 6', 'Ages 2 - 3', 'Ages 7 under',
#        'Ages 9 under', 'Ages 11 under', 'Ages 9 - 18', 'Ages 13 - 18',
#        'Ages 14 - 18', 'Ages 6 - 8', datetime.datetime(2017, 1, 11, 0, 0),
#        'Adult', 'Youth', '15 - 18', '3.5-12',
#        datetime.datetime(2017, 6, 13, 0, 0), '17 & under', '5 and over',
#        datetime.datetime(2017, 7, 9, 0, 0), 'Ages 7 - 19',
#        datetime.datetime(2017, 10, 17, 0, 0),
#        datetime.datetime(2017, 5, 18, 0, 0),
#        datetime.datetime(2017, 9, 21, 0, 0), 'Age 8-18', 'Ages 7-19',
#        'Ages 16-20', 'Ages 7 - 14', 'Ages 6 - 12', 'Ages 13 - up',
#        'Ages 7 - 17', 'Ages 9 - 14', 'Ages 8 - 14', 'Ages 7 - 12',
#        'Ages 12 - 17', 'Ages 8 - 18', 'Ages 5 - 10', 'Ages 13 - 17',
#        'Ages 5 - 17', 'Ages 6 - 15', 'Ages 8 - 10', 'Ages 8 - 17',
#        'Ages 6 - up', 'Ages 6 - 18', 'Ages 5 - 8', 'Ages 11-up',
#        'Ages 13-up', 'Ages 7-up', 'Ages 9-up', 'Ages 14-up', 'Ages 3-up',
#        'Ages 4-up', 'Ages 6 - 9', 'Ages 5 - 15', 'Ages 10 - 14',
#        'Ages 4 - 15', 'Ages 3 - 5', 'Ages 6 - 11', 'Ages 12 - 18',
#        'Ages 11 - 18', 'Ages 7 - 13', 'Ages 11 - 14', 'Ages 7 - 10',
#        'Ages 7 -10', 'Ages 10 - 13', 'Ages 4 - 16', 'Ages 12 - 15',
#        'Ages 7 - 15', 'Ages 6 - 14', 'Ages 5 - 13', 'Ages 7 - 9',
#        'Ages 7 - 18', 'Ages 3 - 15', 'Ages 3 - 12', 'Age 7 - 17',
#        'Ages 4 - 14', 'Ages 6 - 16', 'Ages 7  - 17', 'Ages 12 - up',
#        'Ages 3 - 11', 'Ages 9 - up', 'Ages 6 - 7', 'Ages 8 - 9',
#        'Ages 9 - 17', 'Not available', 'Ages 12 - 14', 'Ages 10 - up',
#        'Ages 10 - 15', 'Ages 10-up', 'Ages 15-up', 'Ages 3 ', 'Ages 3 -4',
#        'Ages 6', 'Ages 1-7', 'Ages 1-4', 'Ages 16-24', 'Ages 2 - 12',
#        'Ages 4 - 18', 'Ages 7 - up', 'Ages 13 - 21', 'Ages 9 - 16',
#        'Ages 9 - 13', 'Ages 16-17', 'Ages 18-99', 'Ages 13-99',
#        'Ages 8 -18', '6 to 12', datetime.datetime(2017, 3, 8, 0, 0),
#        datetime.datetime(2017, 2, 8, 0, 0), '9 to 12', 'Ages 8- 18',
#        'Ages 20-30', 'Ages 13-22', 'Ages 8-20', 'Ages 5 to 8',
#        'Ages 5 to 15', 'Ages 6 to 14', 'Ages 10 to 14', 'Ages 7 to 8',
#        'Ages 9 - 10', 'Ages 11 to 13', 'Ages 10 to 17', 'Ages 5 to 13',
#        'Ages 5 to 7', 'Ages 11 to 14', 'Ages 8 to 17', 'Ages 12 to 15',
#        'Ages 9 to 15', 'Ages 4 to 9', 'Ages 12 to 18', 'Ages 9 to 13',
#        'Aged 7 to 12', 'Ages 3 to 6', 'Ages 7 to 17', 'Ages 11 to 16',
#        'ages 14-16', 'ages 13-15', 'Ages 10 to 16', 'Ages 6 to 10',
#        'Ages 4 to 14', 'Ages 3 to 12', 'Ages 15 to 20', 'Ages 8 to 11',
#        'Ages 12 to 14', 'Ages 8 to 18', 'Ages 6 to 11', 'Ages 4 to 16',
#        'ages 19-21', 'Ages 8 to 16', 'Ages 6 to 12', 'Ages 5 to 18',
#        'Ages 11 to 17', '5-7 year-olds', '6-7 years old',
#        '11-13 year olds', '8-10 years old', '4-5 years old',
#        '4-5 yr olds', 'Ages: 5 - 15', 'Ages 12 & up', 'Ages 13 & up',
#        'Ages 13 and older', '7-9 years old', '4-6 years old',
#        'Ages 6 & Up', '6-15 years old', 'ages 6-18', 'ages 4-15',
#        'ages 4-6', 'ages 4-12', 'ages 4-8', 'Ages 11+', '3 & 4 year olds',
#        'Ages 9 & 10', 'Ages 13 & 14', '6-17 years old', '5-14 years old',
#        'ages 5 & 6', 'ages 8 - 16', 'ages 3-4', 'ages 11-13',
#        'ages 13-18', 'ages 7-15', 'Ages 3-14', 'Age 6 - 12', ' Ages 5-12',
#        'Ages 6 up', 'ages 7-16', 'Ages 2.5 to 4', 'Ages 5 and 6',
#        'Age 5-16', 'Ages 6 months - 3 years', 'Ages 3 -5', 'Ages 4-21',
#        'Ages 17 and up', 'Ages 10 and up', 'Age 8 - 17', 'Age 5 - 15',
#        'Age 6 - 15', 'Age 8 - 15', 'Age 5 - 12', 'Age 10 - 12',
#        'Age 7 - 15', 'Age 7 - 12', 'Age 8 - 16', 'ages 8-16',
#        'Age 13 - 18', 'Age 6 - 9', 'Age 10 - 14', 'Age 8 - 14',
#        'Age 12 - 14', 'Age 15 - 18', 'Age 13 - up', 'Age 14 - 20',
#        'Age 8u - 13u', 'Age 8 - 13', 'Age 9u - 13u', 'Age 11u - 13u',
#        'Age 6 - 11', 'Age 12 - 100', 'Age 5 - 18', 'Age 5 -7',
#        'Age 3 - 4', 'Age 7 - 10', 'Age 11 - 15', 'Age 6 - 16',
#        'Age 9 -17', 'Age 9 - 17', 'age 9-17', 'Age 4 - 6', 'Age 13U - up',
#        'Age 9 - 15', 'age 8-18', 'Age 7 - 14', 'Age 7 - 11', 'Age 7 - 13',
#        'Age 8 - 10', 'Age 5 - 8', 'Age 9 - 16', 'Age 6 - 18',
#        'Age 6 - 17', 'Age 12 - 17', 'Age 7 - 16', 'Age 5 - 16',
#        'Age 8 - 18', 'age 6-14', 'Age 7 - 18', 'Age 8 - 12', 'Age 3 - 5',
#        'Age 13 - 19', 'Age 5 - 11', 'Age 8 - up', 'Age 5 - 9',
#        'Age 11 - up', 'Age 10 - up', 'Age 3-17', 'Ages 13 - 16',
#        'Ages 8 - 12', 'Ages 5 - 7', 'ages 15 and up', 'Age 16U ',
#        'Age 12 - 18', 'Age 8 - 11', 'Age 2 - up', 'ages 18 and up',
#        'Ages 12-under', 'Ages 9-8', 'Age 14 - 17', 'Ages 0-14',
#        'Ages 16-21', 'Ages 3-11', '3.5 -12',
#        datetime.datetime(2017, 4, 15, 0, 0), '15-18'], dtype=object)

# %%
np5 = np4
np5
# Out:
#                                         Sports Camp Name Sports Offered  \
# 0           Alabama A&M University 2016 Fundamental Camp       Baseball
# 1      Alabama A&M University 2016 Summer Skills Clin...       Baseball
# 2      Alabama A&M University 2016 Summer Skills Clin...       Baseball
# 3      Alabama A&M University 2016 Summer Skills Clin...       Baseball
# 4                   Alabama A&M University Showcase Camp       Baseball
# ...                                                  ...            ...
# 26375  University of Wyoming - Volleyball Elite Camp ...     Volleyball
# 26376  University of Wyoming - Volleyball Skills Camp...     Volleyball
# 26377  University of Wyoming - Volleyball Skills Camp...     Volleyball
# 26378  University of Wyoming - Volleyball Team Camp (...     Volleyball
# 26379  University of Wyoming - Volleyball Team Camp (...     Volleyball
#
#                                                   Skills  \
# 0                                             all skills
# 1      Techniques, drills and skill specific exercise...
# 2      Techniques, drills and skill specific exercise...
# 3      Techniques, drills and skill specific exercise...
# 4                                             all skills
# ...                                                  ...
# 26375  Camp will involve more advanced skill instruct...
# 26376  Camp are designed for the beginner to intermed...
# 26377  Camp are designed for the beginner to intermed...
# 26378  Camp is a great opportunity for Middle & High ...
# 26379  Camp is a great opportunity for Middle & High ...
#
#                                   Required Skill Level Gender            Age  \
# 0      Novice, Beginner, Intermediate, Advanced, Elite      B      Ages 7-14
# 1                                         Intermediate      B  not available
# 2                                         Intermediate      B  not available
# 3                                         Intermediate      B  not available
# 4      Novice, Beginner, Intermediate, Advanced, Elite      B  not available
# ...                                                ...    ...            ...
# 26375                           Intermediate, Advanced      F      Ages 0-99
# 26376                           Beginner, Intermediate      F      Ages 0-99
# 26377                           Beginner, Intermediate      F      Ages 0-99
# 26378                           Intermediate, Advanced      F      Ages 0-99
# 26379                           Intermediate, Advanced      F      Ages 0-99
#
#                    Schedule Asssociated Organization        City State Region  \
# 0                 Half Week   Alabama A&M University  Hunstville    AL     SE
# 1                  Full Day   Alabama A&M University  Hunstville    AL     SE
# 2                  Full Day   Alabama A&M University  Hunstville    AL     SE
# 3                  Full Day   Alabama A&M University  Hunstville    AL     SE
# 4                 Half Week   Alabama A&M University  Hunstville    AL     SE
# ...                     ...                      ...         ...   ...    ...
# 26375  Overnight, Half Week    University of Wyoming     Laramie    WY     NW
# 26376   Full Day, Half Week    University of Wyoming     Laramie    WY     NW
# 26377  Overnight, Half Week    University of Wyoming     Laramie    WY     NW
# 26378   Full Day, Half Week    University of Wyoming     Laramie    WY     NW
# 26379  Overnight, Half Week    University of Wyoming     Laramie    WY     NW
#
#       Capacity        Price Contact Person         Position of Contact Person  \
# 0        1-100         $105     Mitch Mill                         Head Coach
# 1        1-100  $100 - $195     Mitch Mill                         Head Coach
# 2        1-100  $100 - $195     Mitch Mill                         Head Coach
# 3        1-100  $100 - $195     Mitch Mill                         Head Coach
# 4        1-100          $80     Mitch Mill                         Head Coach
# ...        ...          ...            ...                                ...
# 26375    1-100          260  Kindra Gillen  Camp Coordinator, Assistant Coach
# 26376    1-100    $235-$275  Kindra Gillen  Camp Coordinator, Assistant Coach
# 26377    1-100          365  Kindra Gillen  Camp Coordinator, Assistant Coach
# 26378    1-100    $235-$275  Kindra Gillen  Camp Coordinator, Assistant Coach
# 26379    1-100          365  Kindra Gillen  Camp Coordinator, Assistant Coach
#
#       Camp Email Address    Phone Number Complete?
# 0          info@aamu.edu  (256) 372-5000       YES
# 1          info@aamu.edu  (256) 372-5000       YES
# 2          info@aamu.edu  (256) 372-5000       YES
# 3          info@aamu.edu  (256) 372-5000       YES
# 4          info@aamu.edu  (256) 372-5000       YES
# ...                  ...             ...       ...
# 26375   kgillen@uwyo.edu    307-766-4805       YES
# 26376   kgillen@uwyo.edu    307-766-4805       YES
# 26377   kgillen@uwyo.edu    307-766-4805       YES
# 26378   kgillen@uwyo.edu    307-766-4805       YES
# 26379   kgillen@uwyo.edu    307-766-4805       YES
#
# [26380 rows x 18 columns]

# %%
np5 = np5.dropna(subset=["Age"])

# %%
np5.shape
# Out:
# (19652, 18)

# %%
np5
# Out:
#                                         Sports Camp Name Sports Offered  \
# 0           Alabama A&M University 2016 Fundamental Camp       Baseball
# 1      Alabama A&M University 2016 Summer Skills Clin...       Baseball
# 2      Alabama A&M University 2016 Summer Skills Clin...       Baseball
# 3      Alabama A&M University 2016 Summer Skills Clin...       Baseball
# 4                   Alabama A&M University Showcase Camp       Baseball
# ...                                                  ...            ...
# 26375  University of Wyoming - Volleyball Elite Camp ...     Volleyball
# 26376  University of Wyoming - Volleyball Skills Camp...     Volleyball
# 26377  University of Wyoming - Volleyball Skills Camp...     Volleyball
# 26378  University of Wyoming - Volleyball Team Camp (...     Volleyball
# 26379  University of Wyoming - Volleyball Team Camp (...     Volleyball
#
#                                                   Skills  \
# 0                                             all skills
# 1      Techniques, drills and skill specific exercise...
# 2      Techniques, drills and skill specific exercise...
# 3      Techniques, drills and skill specific exercise...
# 4                                             all skills
# ...                                                  ...
# 26375  Camp will involve more advanced skill instruct...
# 26376  Camp are designed for the beginner to intermed...
# 26377  Camp are designed for the beginner to intermed...
# 26378  Camp is a great opportunity for Middle & High ...
# 26379  Camp is a great opportunity for Middle & High ...
#
#                                   Required Skill Level Gender            Age  \
# 0      Novice, Beginner, Intermediate, Advanced, Elite      B      Ages 7-14
# 1                                         Intermediate      B  not available
# 2                                         Intermediate      B  not available
# 3                                         Intermediate      B  not available
# 4      Novice, Beginner, Intermediate, Advanced, Elite      B  not available
# ...                                                ...    ...            ...
# 26375                           Intermediate, Advanced      F      Ages 0-99
# 26376                           Beginner, Intermediate      F      Ages 0-99
# 26377                           Beginner, Intermediate      F      Ages 0-99
# 26378                           Intermediate, Advanced      F      Ages 0-99
# 26379                           Intermediate, Advanced      F      Ages 0-99
#
#                    Schedule Asssociated Organization        City State Region  \
# 0                 Half Week   Alabama A&M University  Hunstville    AL     SE
# 1                  Full Day   Alabama A&M University  Hunstville    AL     SE
# 2                  Full Day   Alabama A&M University  Hunstville    AL     SE
# 3                  Full Day   Alabama A&M University  Hunstville    AL     SE
# 4                 Half Week   Alabama A&M University  Hunstville    AL     SE
# ...                     ...                      ...         ...   ...    ...
# 26375  Overnight, Half Week    University of Wyoming     Laramie    WY     NW
# 26376   Full Day, Half Week    University of Wyoming     Laramie    WY     NW
# 26377  Overnight, Half Week    University of Wyoming     Laramie    WY     NW
# 26378   Full Day, Half Week    University of Wyoming     Laramie    WY     NW
# 26379  Overnight, Half Week    University of Wyoming     Laramie    WY     NW
#
#       Capacity        Price Contact Person         Position of Contact Person  \
# 0        1-100         $105     Mitch Mill                         Head Coach
# 1        1-100  $100 - $195     Mitch Mill                         Head Coach
# 2        1-100  $100 - $195     Mitch Mill                         Head Coach
# 3        1-100  $100 - $195     Mitch Mill                         Head Coach
# 4        1-100          $80     Mitch Mill                         Head Coach
# ...        ...          ...            ...                                ...
# 26375    1-100          260  Kindra Gillen  Camp Coordinator, Assistant Coach
# 26376    1-100    $235-$275  Kindra Gillen  Camp Coordinator, Assistant Coach
# 26377    1-100          365  Kindra Gillen  Camp Coordinator, Assistant Coach
# 26378    1-100    $235-$275  Kindra Gillen  Camp Coordinator, Assistant Coach
# 26379    1-100          365  Kindra Gillen  Camp Coordinator, Assistant Coach
#
#       Camp Email Address    Phone Number Complete?
# 0          info@aamu.edu  (256) 372-5000       YES
# 1          info@aamu.edu  (256) 372-5000       YES
# 2          info@aamu.edu  (256) 372-5000       YES
# 3          info@aamu.edu  (256) 372-5000       YES
# 4          info@aamu.edu  (256) 372-5000       YES
# ...                  ...             ...       ...
# 26375   kgillen@uwyo.edu    307-766-4805       YES
# 26376   kgillen@uwyo.edu    307-766-4805       YES
# 26377   kgillen@uwyo.edu    307-766-4805       YES
# 26378   kgillen@uwyo.edu    307-766-4805       YES
# 26379   kgillen@uwyo.edu    307-766-4805       YES
#
# [19652 rows x 18 columns]

# %%
#to make the age column free of all the alphabets, special characters
age = np5["Age"].str.extract(r'(\d\S*)',expand=True)

# %%
age
# Out:
#           0
# 0      7-14
# 1       NaN
# 2       NaN
# 3       NaN
# 4       NaN
# ...     ...
# 26375  0-99
# 26376  0-99
# 26377  0-99
# 26378  0-99
# 26379  0-99
#
# [19652 rows x 1 columns]

# %%
age[0].unique()
# Out:
# array(['7-14', nan, '14-18', '6-12', '6-17', '9-12', '5-11', '8-18', '11',
#        '18', '10-18', '5', '7', '9', '6-11', '7-18', '12-18', '5-18',
#        '5-12', '3-6', '3-12', '8-15', '8-12', '12-19', '9-11', '8-16',
#        '14', '15', '7-11', '12', '4-6', '6-18', '16-19', '9-18', '10',
#        '10-17', '6-10', '13-19', '7-10', '9-10', '6', '4-13', '11-19',
#        '11-14', '6-13', '0-99', '7-16', '12-17', '6-14', '5-10', '15-19',
#        '4-9', '10-14', '4-14', '5-15', '15-18', '7-15', '10-12', '11-12',
#        '4-18', '5-14', '8', '11-18', '9-14', '12-16', '6-9', '8-13',
#        '8-14', '8-11', '9-16', '7-13', '0-1', '6-15', '2-2', '5-5', '4-4',
#        '1-1', '3-4', '3-5', '4-8', '6-8', '1-3', '2-5', '1-5', '1-8',
#        '8-17', '6-16', '14-21', '10-19', '5-6', '3-18', '4-12', '2-12',
#        '1-2', '5-17', '2-4', '0-2', '12-15', '2-18', '7-17', '7-12',
#        '13-17', '13-18', '1-18', '1-10', '12-14', '4-17', '9-15', '7-9',
#        '1-11', '1-12', '13-14', '9-17', '6-22', '9-22', '14-19', '13-21',
#        '5-13', '14-20', '14-17', '5-8', '4-7', '2-8', '10-15', '3-13',
#        '13-16', '21-25', '5-16', '3-15', '4', '4-11', '3-16', '3-10',
#        '11-17', '9-99', '0-9', '6-99', '3-99', '8-99', '13-20', '9-13',
#        '14-22', '10-13', '5-9', '3-8', '3-7', '3', '7-8', '12-20', '13',
#        '8-19', '11-13', '10-16', '8-9', '6-7', '13-15', '5-7', '4-5',
#        '4-10', '10-11', '12-13', '11-15', '8-10', '14-30', '2-3', '21-23',
#        '15-17', '18+', '16-18', '17-20', '18-21', '18-20', '15-16',
#        '3-17', '0-13', '0-18', '11-16', '0-10', '16', '14-15', '17-18',
#        '1.2-3', '14-16', '4-15', '9-19', '9-20', '9-21', '9-23', '9-24',
#        '9-25', '9-26', '9-27', '9-28', '9-29', '9-30', '9-31', '9-32',
#        '1.5-2', '2-7', '5-19', '0-3', '3.5-6', '9-10,', '5-6,', '7u-10u',
#        '11u-14u', '9U', '10U', '11U', '12U', '7U,', '3.5', '14-23',
#        '2-10', '16-17', '1-13', '9th-12th', '18-0', '4.5-6', '4.5-7',
#        '3-4.5', '2', '2½', '3.5-12', '17', '7-19', '16-20', '11-up',
#        '13-up', '7-up', '9-up', '14-up', '3-up', '4-up', '10-up', '15-up',
#        '1-7', '1-4', '16-24', '18-99', '13-99', '8-', '20-30', '13-22',
#        '8-20', '19-21', '11+', '3-14', '2.5', '4-21', '8u', '9u', '11u',
#        '13U', '16U', '12-under', '9-8', '0-14', '16-21', '3-11'],
#       dtype=object)

# %%
age = age[0].apply(lambda x: pd.Series(str(x).split(r'(\D)')))

# %%
age.head(10)
# Out:
#        0
# 0   7-14
# 1    nan
# 2    nan
# 3    nan
# 4    nan
# 5  14-18
# 6  14-18
# 7    nan
# 8   6-12
# 9    nan

# %%
age[0].unique()
# Out:
# array(['7-14', 'nan', '14-18', '6-12', '6-17', '9-12', '5-11', '8-18',
#        '11', '18', '10-18', '5', '7', '9', '6-11', '7-18', '12-18',
#        '5-18', '5-12', '3-6', '3-12', '8-15', '8-12', '12-19', '9-11',
#        '8-16', '14', '15', '7-11', '12', '4-6', '6-18', '16-19', '9-18',
#        '10', '10-17', '6-10', '13-19', '7-10', '9-10', '6', '4-13',
#        '11-19', '11-14', '6-13', '0-99', '7-16', '12-17', '6-14', '5-10',
#        '15-19', '4-9', '10-14', '4-14', '5-15', '15-18', '7-15', '10-12',
#        '11-12', '4-18', '5-14', '8', '11-18', '9-14', '12-16', '6-9',
#        '8-13', '8-14', '8-11', '9-16', '7-13', '0-1', '6-15', '2-2',
#        '5-5', '4-4', '1-1', '3-4', '3-5', '4-8', '6-8', '1-3', '2-5',
#        '1-5', '1-8', '8-17', '6-16', '14-21', '10-19', '5-6', '3-18',
#        '4-12', '2-12', '1-2', '5-17', '2-4', '0-2', '12-15', '2-18',
#        '7-17', '7-12', '13-17', '13-18', '1-18', '1-10', '12-14', '4-17',
#        '9-15', '7-9', '1-11', '1-12', '13-14', '9-17', '6-22', '9-22',
#        '14-19', '13-21', '5-13', '14-20', '14-17', '5-8', '4-7', '2-8',
#        '10-15', '3-13', '13-16', '21-25', '5-16', '3-15', '4', '4-11',
#        '3-16', '3-10', '11-17', '9-99', '0-9', '6-99', '3-99', '8-99',
#        '13-20', '9-13', '14-22', '10-13', '5-9', '3-8', '3-7', '3', '7-8',
#        '12-20', '13', '8-19', '11-13', '10-16', '8-9', '6-7', '13-15',
#        '5-7', '4-5', '4-10', '10-11', '12-13', '11-15', '8-10', '14-30',
#        '2-3', '21-23', '15-17', '18+', '16-18', '17-20', '18-21', '18-20',
#        '15-16', '3-17', '0-13', '0-18', '11-16', '0-10', '16', '14-15',
#        '17-18', '1.2-3', '14-16', '4-15', '9-19', '9-20', '9-21', '9-23',
#        '9-24', '9-25', '9-26', '9-27', '9-28', '9-29', '9-30', '9-31',
#        '9-32', '1.5-2', '2-7', '5-19', '0-3', '3.5-6', '9-10,', '5-6,',
#        '7u-10u', '11u-14u', '9U', '10U', '11U', '12U', '7U,', '3.5',
#        '14-23', '2-10', '16-17', '1-13', '9th-12th', '18-0', '4.5-6',
#        '4.5-7', '3-4.5', '2', '2½', '3.5-12', '17', '7-19', '16-20',
#        '11-up', '13-up', '7-up', '9-up', '14-up', '3-up', '4-up', '10-up',
#        '15-up', '1-7', '1-4', '16-24', '18-99', '13-99', '8-', '20-30',
#        '13-22', '8-20', '19-21', '11+', '3-14', '2.5', '4-21', '8u', '9u',
#        '11u', '13U', '16U', '12-under', '9-8', '0-14', '16-21', '3-11'],
#       dtype=object)

# %%
#age = np5["Age"].str.extract('(\d)',expand=True)

# %%
age = age.rename(columns={0: "Age"})

# %%
age.head(20)
# Out:
#       Age
# 0    7-14
# 1     nan
# 2     nan
# 3     nan
# 4     nan
# 5   14-18
# 6   14-18
# 7     nan
# 8    6-12
# 9     nan
# 10    nan
# 11    nan
# 12   6-17
# 13   6-17
# 14    nan
# 15    nan
# 16    nan
# 17    nan
# 18    nan
# 19   9-12

# %%
sp=age
sp.head()
# Out:
#     Age
# 0  7-14
# 1   nan
# 2   nan
# 3   nan
# 4   nan

# %%
#splitting the data with regular expressions which are non digits
sp = sp["Age"].apply(lambda x: pd.Series(str(x).split(r'\D')))

# %%
#split the data where you see dashes
sp = sp[0].apply(lambda x: pd.Series(str(x).split("-")))

# %%
sp.head(30)
# Out:
#       0    1
# 0     7   14
# 1   nan  NaN
# 2   nan  NaN
# 3   nan  NaN
# 4   nan  NaN
# 5    14   18
# 6    14   18
# 7   nan  NaN
# 8     6   12
# 9   nan  NaN
# 10  nan  NaN
# 11  nan  NaN
# 12    6   17
# 13    6   17
# 14  nan  NaN
# 15  nan  NaN
# 16  nan  NaN
# 17  nan  NaN
# 18  nan  NaN
# 19    9   12
# 20    5   11
# 21  nan  NaN
# 22  nan  NaN
# 23  nan  NaN
# 24  nan  NaN
# 25  nan  NaN
# 26  nan  NaN
# 27  nan  NaN
# 28  nan  NaN
# 29  nan  NaN

# %%
sp = sp.rename(columns={0: "AgeFirst",1:"AgeSecond"})

# %%
sp
# Out:
#       AgeFirst AgeSecond  0-10
# 0            7        14   NaN
# 1          NaN       NaN   NaN
# 2          NaN       NaN   NaN
# 3          NaN       NaN   NaN
# 4          NaN       NaN   NaN
# ...        ...       ...   ...
# 26375        0        99   NaN
# 26376        0        99   NaN
# 26377        0        99   NaN
# 26378        0        99   NaN
# 26379        0        99   NaN
#
# [19652 rows x 3 columns]

# %%
sp["AgeFirst"].unique()
# Out:
# array(['7', 'nan', '14', '6', '9', '5', '8', '11', '18', '10', '12', '3',
#        '15', '4', '16', '13', '0', '2', '1', '21', '18+', '17', '1.2',
#        '1.5', '3.5', '7u', '11u', '9U', '10U', '11U', '12U', '7U,', '9th',
#        '4.5', '2½', '20', '19', '11+', '2.5', '8u', '9u', '13U', '16U'],
#       dtype=object)

# %%
sp["AgeSecond"].unique()
# Out:
# array(['14', nan, '18', '12', '17', '11', '6', '15', '19', '16', '10',
#        '13', '99', '9', '1', '2', '5', '4', '8', '3', '21', '22', '20',
#        '7', '25', '30', '23', '24', '26', '27', '28', '29', '31', '32',
#        '10,', '6,', '10u', '14u', '12th', '0', '4.5', 'up', '', 'under'],
#       dtype=object)

# %%
sp1 = sp

# %%
sp1.head()
# Out:
#   AgeFirst AgeSecond  0-10
# 0        7        14   NaN
# 1      NaN       NaN   NaN
# 2      NaN       NaN   NaN
# 3      NaN       NaN   NaN
# 4      NaN       NaN   NaN

# %%
#sp1= sp1.fillna(0)
#sp1["AgeSecond"] = sp1["AgeSecond"].apply(lambda x: pd.Series(str(x).split(r'\D)))
#sp1 = sp1["AgeFirst"].apply(lambda x: pd.Series(str(x).split(r'\D')))
#sp2 =sp1["AgeFirst"].apply(lambda x: pd.Series(str(x).split(r'\d*')))
#sp1
#sp = sp.dropna(how="all")
#sp1.AgeFirst.unique()
#sp1["AgeFirst"] = sp1["AgeFirst"].replace(numpy.nan, 0)
#sp1.AgeFirst.unique()

# %%
sp1["AgeFirst"] = sp1["AgeFirst"].str.extract(r'(\d*)',expand=True)
sp1["AgeSecond"] = sp1["AgeSecond"].str.extract(r'(\d*)',expand=True)

# %%
sp1
# Out:
#       AgeFirst AgeSecond  0-10
# 0            7        14   NaN
# 1          NaN       NaN   NaN
# 2          NaN       NaN   NaN
# 3          NaN       NaN   NaN
# 4          NaN       NaN   NaN
# ...        ...       ...   ...
# 26375        0        99   NaN
# 26376        0        99   NaN
# 26377        0        99   NaN
# 26378        0        99   NaN
# 26379        0        99   NaN
#
# [19652 rows x 3 columns]

# %%
sp1["AgeSecond"].unique()
# Out:
# array(['14', nan, '18', '12', '17', '11', '6', '15', '19', '16', '10',
#        '13', '99', '9', '1', '2', '5', '4', '8', '3', '21', '22', '20',
#        '7', '25', '30', '23', '24', '26', '27', '28', '29', '31', '32',
#        '0'], dtype=object)

# %%
#trying to put 0's in the place of NaN
sp1["AgeSecond"] = sp1["AgeSecond"].replace('', numpy.NaN)

# %%
sp1["AgeSecond"].unique()
# Out:
# array(['14', nan, '18', '12', '17', '11', '6', '15', '19', '16', '10',
#        '13', '99', '9', '1', '2', '5', '4', '8', '3', '21', '22', '20',
#        '7', '25', '30', '23', '24', '26', '27', '28', '29', '31', '32',
#        '0'], dtype=object)

# %%
sp1["AgeFirst"] = sp1["AgeFirst"].replace('', numpy.NaN)

# %%
# sp1["AgeSecond"] = sp1["AgeSecond"].replace(numpy.NaN,'0')
# sp1["AgeFirst"] = sp1["AgeFirst"].replace(numpy.NaN,'0')

# %%
sp1
# Out:
#       AgeFirst AgeSecond  0-10
# 0            7        14   NaN
# 1          NaN       NaN   NaN
# 2          NaN       NaN   NaN
# 3          NaN       NaN   NaN
# 4          NaN       NaN   NaN
# ...        ...       ...   ...
# 26375        0        99   NaN
# 26376        0        99   NaN
# 26377        0        99   NaN
# 26378        0        99   NaN
# 26379        0        99   NaN
#
# [19652 rows x 3 columns]

# %%
#sp1["AgeSecond"] = sp1["AgeSecond"].astype(str).astype(int)

# %%
#sp1["AgeFirst"] = sp1["AgeFirst"].astype(str).astype(int)

# %%
from numpy import asarray
from sklearn.preprocessing import OneHotEncoder

# %%
sp2 = sp1

# %%
sp2
# Out:
#       AgeFirst AgeSecond  0-10
# 0            7        14   NaN
# 1            0       NaN   NaN
# 2            0       NaN   NaN
# 3            0       NaN   NaN
# 4            0       NaN   NaN
# ...        ...       ...   ...
# 26375        0        99   NaN
# 26376        0        99   NaN
# 26377        0        99   NaN
# 26378        0        99   NaN
# 26379        0        99   NaN
#
# [19652 rows x 3 columns]

# %%
sp2["0-10"] = sp2["0-10"].replace("",numpy.NaN)

# %%
sp2 = sp2.reindex(sp2.columns.tolist() + ['11-20','21-30','31-40','41-50','51-60','61-70','71-80','81-90','90+'], axis=1)

# %%
sp2
# Out:
#       AgeFirst AgeSecond  0-10  11-20  21-30  31-40  41-50  51-60  61-70  \
# 0            7        14   NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 1            0       NaN   NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 2            0       NaN   NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 3            0       NaN   NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 4            0       NaN   NaN    NaN    NaN    NaN    NaN    NaN    NaN
# ...        ...       ...   ...    ...    ...    ...    ...    ...    ...
# 26375        0        99   NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 26376        0        99   NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 26377        0        99   NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 26378        0        99   NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 26379        0        99   NaN    NaN    NaN    NaN    NaN    NaN    NaN
#
#        71-80  81-90  90+
# 0        NaN    NaN  NaN
# 1        NaN    NaN  NaN
# 2        NaN    NaN  NaN
# 3        NaN    NaN  NaN
# 4        NaN    NaN  NaN
# ...      ...    ...  ...
# 26375    NaN    NaN  NaN
# 26376    NaN    NaN  NaN
# 26377    NaN    NaN  NaN
# 26378    NaN    NaN  NaN
# 26379    NaN    NaN  NaN
#
# [19652 rows x 12 columns]

# %%
sp2.iloc[0,0]
# Out:
# 7

# %%
sp2["AgeSecond"] = sp2["AgeSecond"].replace(numpy.NaN,'0')
sp2["AgeFirst"] = sp2["AgeFirst"].replace(numpy.NaN,'0')

# %%
sp2["AgeFirst"] = sp2["AgeFirst"].astype(str).astype(int)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-158-8a237527fee8> in <module>
# ----> 1 sp2["AgeFirst"] = sp2["AgeFirst"].astype(str).astype(int)
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/core/generic.py in astype(self, dtype, copy, errors)
#    5696         else:
#    5697             # else, only a single dtype is given
# -> 5698             new_data = self._data.astype(dtype=dtype, copy=copy, errors=errors)
#    5699             return self._constructor(new_data).__finalize__(self)
#    5700
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/core/internals/managers.py in astype(self, dtype, copy, errors)
#     580
#     581     def astype(self, dtype, copy: bool = False, errors: str = "raise"):
# --> 582         return self.apply("astype", dtype=dtype, copy=copy, errors=errors)
#     583
#     584     def convert(self, **kwargs):
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/core/internals/managers.py in apply(self, f, filter, **kwargs)
#     440                 applied = b.apply(f, **kwargs)
#     441             else:
# --> 442                 applied = getattr(b, f)(**kwargs)
#     443             result_blocks = _extend_blocks(applied, result_blocks)
#     444
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/core/internals/blocks.py in astype(self, dtype, copy, errors)
#     623             vals1d = values.ravel()
#     624             try:
# --> 625                 values = astype_nansafe(vals1d, dtype, copy=True)
#     626             except (ValueError, TypeError):
#     627                 # e.g. astype_nansafe can fail on object-dtype of strings
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/core/dtypes/cast.py in astype_nansafe(arr, dtype, copy, skipna)
#     872         # work around NumPy brokenness, #1987
#     873         if np.issubdtype(dtype.type, np.integer):
# --> 874             return lib.astype_intsafe(arr.ravel(), dtype).reshape(arr.shape)
#     875
#     876         # if we have a datetime/timedelta array of objects
#
# pandas/_libs/lib.pyx in pandas._libs.lib.astype_intsafe()
#
# ValueError: invalid literal for int() with base 10: 'nan'

# %%
sp2["AgeSecond"] = sp2["AgeSecond"].astype(str).astype(int)

# %%
sp2.iloc
# Out:
#        AgeFirst  AgeSecond  0-10  11-20  21-30  31-40  41-50  51-60  61-70  \
# 0             7         14   NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 1             0          0   NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 2             0          0   NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 3             0          0   NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 4             0          0   NaN    NaN    NaN    NaN    NaN    NaN    NaN
# ...         ...        ...   ...    ...    ...    ...    ...    ...    ...
# 26375         0         99   NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 26376         0         99   NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 26377         0         99   NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 26378         0         99   NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 26379         0         99   NaN    NaN    NaN    NaN    NaN    NaN    NaN
#
#        71-80  81-90  90+
# 0        NaN    NaN  NaN
# 1        NaN    NaN  NaN
# 2        NaN    NaN  NaN
# 3        NaN    NaN  NaN
# 4        NaN    NaN  NaN
# ...      ...    ...  ...
# 26375    NaN    NaN  NaN
# 26376    NaN    NaN  NaN
# 26377    NaN    NaN  NaN
# 26378    NaN    NaN  NaN
# 26379    NaN    NaN  NaN
#
# [19652 rows x 12 columns]

# %%
sp2["0-10"].iloc[0] = "0"
# Out:
# C:\Users\vidhi\anaconda3\lib\site-packages\pandas\core\indexing.py:670: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_with_indexer(indexer, value)

# %%
sp2
# Out:
#        AgeFirst  AgeSecond 0-10  11-20  21-30  31-40  41-50  51-60  61-70  \
# 0             7         14    0    NaN    NaN    NaN    NaN    NaN    NaN
# 1             0          0  NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 2             0          0  NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 3             0          0  NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 4             0          0  NaN    NaN    NaN    NaN    NaN    NaN    NaN
# ...         ...        ...  ...    ...    ...    ...    ...    ...    ...
# 26375         0         99  NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 26376         0         99  NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 26377         0         99  NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 26378         0         99  NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 26379         0         99  NaN    NaN    NaN    NaN    NaN    NaN    NaN
#
#        71-80  81-90  90+
# 0        NaN    NaN  NaN
# 1        NaN    NaN  NaN
# 2        NaN    NaN  NaN
# 3        NaN    NaN  NaN
# 4        NaN    NaN  NaN
# ...      ...    ...  ...
# 26375    NaN    NaN  NaN
# 26376    NaN    NaN  NaN
# 26377    NaN    NaN  NaN
# 26378    NaN    NaN  NaN
# 26379    NaN    NaN  NaN
#
# [19652 rows x 12 columns]

# %%
r,c = sp2.shape

# %%
r
# Out:
# 19652

# %%
for i in range(r):
    tempAgeFirst = sp2["AgeFirst"].iloc[i]
    tempAgeSecond = sp2["AgeSecond"].iloc[i]
    
    if (tempAgeFirst >= 0 and tempAgeFirst <=10):
        sp2["0-10"].iloc[i]="1"
    elif(tempAgeFirst >= 11 and tempAgeFirst <=20):
        sp2["11-20"].iloc[i]="1"
    elif (tempAgeFirst >= 21 and tempAgeFirst <=30):
        sp2["21-30"].iloc[i]="1"
    elif (tempAgeFirst >= 31 and tempAgeFirst <=40):
        sp2["31-40"].iloc[i]="1"
    elif (tempAgeFirst >= 41 and tempAgeFirst <=50):
        sp2["41-50"].iloc[i]="1"
    elif (tempAgeFirst >= 51 and tempAgeFirst <=60):
        sp2["51-60"].iloc[i]="1"
    elif (tempAgeFirst >= 61 and tempAgeFirst <=70):
        sp2["61-70"].iloc[i]="1"
    elif (tempAgeFirst >= 71 and tempAgeFirst <=80):
        sp2["70-81"].iloc[i]="1"
    elif(tempAgeFirst >= 81 and tempAgeFirst <=90):
        sp2["81-90"].iloc[i]="1"
    elif(tempAgeFirst >= 91):
        sp2["90+"].iloc[i]="1"
        
        

    if(tempAgeSecond >= 0 and tempAgeSecond <=10):
        sp2["0-10"].iloc[i]="1"
    elif(tempAgeSecond >= 11 and tempAgeSecond <=20):
        sp2["11-20"].iloc[i]="1"
    elif(tempAgeSecond >= 21 and tempAgeSecond <=30):
        sp2["21-30"].iloc[i]="1"
    elif(tempAgeSecond >= 31 and tempAgeSecond <=40):
        sp2["31-40"].iloc[i]="1"
    elif (tempAgeSecond >= 41 and tempAgeSecond <=50):
        sp2["41-50"].iloc[i]="1"
    elif (tempAgeSecond >= 51 and tempAgeSecond <=60):
        sp2["51-60"].iloc[i]="1"
    elif (tempAgeSecond >= 61 and tempAgeSecond <=70):
        sp2["61-70"].iloc[i]="1"
    elif (tempAgeSecond >= 71 and tempAgeSecond <=80):
        sp2["70-81"].iloc[i]="1"
    elif (tempAgeSecond >= 81 and tempAgeSecond <=90):
        sp2["81-90"].iloc[i]="1"
    elif (tempAgeSecond >= 91):
        sp2["90+"].iloc[i]="1"
# Out:
# C:\Users\vidhi\anaconda3\lib\site-packages\pandas\core\indexing.py:670: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_with_indexer(indexer, value)

# %%
sp2
# Out:
#        AgeFirst  AgeSecond 0-10 11-20 21-30 31-40  41-50  51-60  61-70  71-80  \
# 0             7         14    1     1   NaN   NaN    NaN    NaN    NaN    NaN
# 1             0          0    1   NaN   NaN   NaN    NaN    NaN    NaN    NaN
# 2             0          0    1   NaN   NaN   NaN    NaN    NaN    NaN    NaN
# 3             0          0    1   NaN   NaN   NaN    NaN    NaN    NaN    NaN
# 4             0          0    1   NaN   NaN   NaN    NaN    NaN    NaN    NaN
# ...         ...        ...  ...   ...   ...   ...    ...    ...    ...    ...
# 26375         0         99    1   NaN   NaN   NaN    NaN    NaN    NaN    NaN
# 26376         0         99    1   NaN   NaN   NaN    NaN    NaN    NaN    NaN
# 26377         0         99    1   NaN   NaN   NaN    NaN    NaN    NaN    NaN
# 26378         0         99    1   NaN   NaN   NaN    NaN    NaN    NaN    NaN
# 26379         0         99    1   NaN   NaN   NaN    NaN    NaN    NaN    NaN
#
#        81-90  90+
# 0        NaN  NaN
# 1        NaN  NaN
# 2        NaN  NaN
# 3        NaN  NaN
# 4        NaN  NaN
# ...      ...  ...
# 26375    NaN    1
# 26376    NaN    1
# 26377    NaN    1
# 26378    NaN    1
# 26379    NaN    1
#
# [19652 rows x 12 columns]

# %%
abc = np5
abc
# Out:
#                                         Sports Camp Name Sports Offered  \
# 0           Alabama A&M University 2016 Fundamental Camp       Baseball
# 1      Alabama A&M University 2016 Summer Skills Clin...       Baseball
# 2      Alabama A&M University 2016 Summer Skills Clin...       Baseball
# 3      Alabama A&M University 2016 Summer Skills Clin...       Baseball
# 4                   Alabama A&M University Showcase Camp       Baseball
# ...                                                  ...            ...
# 26375  University of Wyoming - Volleyball Elite Camp ...     Volleyball
# 26376  University of Wyoming - Volleyball Skills Camp...     Volleyball
# 26377  University of Wyoming - Volleyball Skills Camp...     Volleyball
# 26378  University of Wyoming - Volleyball Team Camp (...     Volleyball
# 26379  University of Wyoming - Volleyball Team Camp (...     Volleyball
#
#                                                   Skills  \
# 0                                             all skills
# 1      Techniques, drills and skill specific exercise...
# 2      Techniques, drills and skill specific exercise...
# 3      Techniques, drills and skill specific exercise...
# 4                                             all skills
# ...                                                  ...
# 26375  Camp will involve more advanced skill instruct...
# 26376  Camp are designed for the beginner to intermed...
# 26377  Camp are designed for the beginner to intermed...
# 26378  Camp is a great opportunity for Middle & High ...
# 26379  Camp is a great opportunity for Middle & High ...
#
#                                   Required Skill Level Gender            Age  \
# 0      Novice, Beginner, Intermediate, Advanced, Elite      B      Ages 7-14
# 1                                         Intermediate      B  not available
# 2                                         Intermediate      B  not available
# 3                                         Intermediate      B  not available
# 4      Novice, Beginner, Intermediate, Advanced, Elite      B  not available
# ...                                                ...    ...            ...
# 26375                           Intermediate, Advanced      F      Ages 0-99
# 26376                           Beginner, Intermediate      F      Ages 0-99
# 26377                           Beginner, Intermediate      F      Ages 0-99
# 26378                           Intermediate, Advanced      F      Ages 0-99
# 26379                           Intermediate, Advanced      F      Ages 0-99
#
#                    Schedule Asssociated Organization        City State Region  \
# 0                 Half Week   Alabama A&M University  Hunstville    AL     SE
# 1                  Full Day   Alabama A&M University  Hunstville    AL     SE
# 2                  Full Day   Alabama A&M University  Hunstville    AL     SE
# 3                  Full Day   Alabama A&M University  Hunstville    AL     SE
# 4                 Half Week   Alabama A&M University  Hunstville    AL     SE
# ...                     ...                      ...         ...   ...    ...
# 26375  Overnight, Half Week    University of Wyoming     Laramie    WY     NW
# 26376   Full Day, Half Week    University of Wyoming     Laramie    WY     NW
# 26377  Overnight, Half Week    University of Wyoming     Laramie    WY     NW
# 26378   Full Day, Half Week    University of Wyoming     Laramie    WY     NW
# 26379  Overnight, Half Week    University of Wyoming     Laramie    WY     NW
#
#       Capacity        Price Contact Person         Position of Contact Person  \
# 0        1-100         $105     Mitch Mill                         Head Coach
# 1        1-100  $100 - $195     Mitch Mill                         Head Coach
# 2        1-100  $100 - $195     Mitch Mill                         Head Coach
# 3        1-100  $100 - $195     Mitch Mill                         Head Coach
# 4        1-100          $80     Mitch Mill                         Head Coach
# ...        ...          ...            ...                                ...
# 26375    1-100          260  Kindra Gillen  Camp Coordinator, Assistant Coach
# 26376    1-100    $235-$275  Kindra Gillen  Camp Coordinator, Assistant Coach
# 26377    1-100          365  Kindra Gillen  Camp Coordinator, Assistant Coach
# 26378    1-100    $235-$275  Kindra Gillen  Camp Coordinator, Assistant Coach
# 26379    1-100          365  Kindra Gillen  Camp Coordinator, Assistant Coach
#
#       Camp Email Address    Phone Number Complete?
# 0          info@aamu.edu  (256) 372-5000       YES
# 1          info@aamu.edu  (256) 372-5000       YES
# 2          info@aamu.edu  (256) 372-5000       YES
# 3          info@aamu.edu  (256) 372-5000       YES
# 4          info@aamu.edu  (256) 372-5000       YES
# ...                  ...             ...       ...
# 26375   kgillen@uwyo.edu    307-766-4805       YES
# 26376   kgillen@uwyo.edu    307-766-4805       YES
# 26377   kgillen@uwyo.edu    307-766-4805       YES
# 26378   kgillen@uwyo.edu    307-766-4805       YES
# 26379   kgillen@uwyo.edu    307-766-4805       YES
#
# [19652 rows x 18 columns]

# %%
f_1 = abc.join(sp2, on=None)

# %%
f_1
# Out:
#                                         Sports Camp Name Sports Offered  \
# 0           Alabama A&M University 2016 Fundamental Camp       Baseball
# 1      Alabama A&M University 2016 Summer Skills Clin...       Baseball
# 2      Alabama A&M University 2016 Summer Skills Clin...       Baseball
# 3      Alabama A&M University 2016 Summer Skills Clin...       Baseball
# 4                   Alabama A&M University Showcase Camp       Baseball
# ...                                                  ...            ...
# 26375  University of Wyoming - Volleyball Elite Camp ...     Volleyball
# 26376  University of Wyoming - Volleyball Skills Camp...     Volleyball
# 26377  University of Wyoming - Volleyball Skills Camp...     Volleyball
# 26378  University of Wyoming - Volleyball Team Camp (...     Volleyball
# 26379  University of Wyoming - Volleyball Team Camp (...     Volleyball
#
#                                                   Skills  \
# 0                                             all skills
# 1      Techniques, drills and skill specific exercise...
# 2      Techniques, drills and skill specific exercise...
# 3      Techniques, drills and skill specific exercise...
# 4                                             all skills
# ...                                                  ...
# 26375  Camp will involve more advanced skill instruct...
# 26376  Camp are designed for the beginner to intermed...
# 26377  Camp are designed for the beginner to intermed...
# 26378  Camp is a great opportunity for Middle & High ...
# 26379  Camp is a great opportunity for Middle & High ...
#
#                                   Required Skill Level Gender            Age  \
# 0      Novice, Beginner, Intermediate, Advanced, Elite      B      Ages 7-14
# 1                                         Intermediate      B  not available
# 2                                         Intermediate      B  not available
# 3                                         Intermediate      B  not available
# 4      Novice, Beginner, Intermediate, Advanced, Elite      B  not available
# ...                                                ...    ...            ...
# 26375                           Intermediate, Advanced      F      Ages 0-99
# 26376                           Beginner, Intermediate      F      Ages 0-99
# 26377                           Beginner, Intermediate      F      Ages 0-99
# 26378                           Intermediate, Advanced      F      Ages 0-99
# 26379                           Intermediate, Advanced      F      Ages 0-99
#
#                    Schedule Asssociated Organization        City State  ...  \
# 0                 Half Week   Alabama A&M University  Hunstville    AL  ...
# 1                  Full Day   Alabama A&M University  Hunstville    AL  ...
# 2                  Full Day   Alabama A&M University  Hunstville    AL  ...
# 3                  Full Day   Alabama A&M University  Hunstville    AL  ...
# 4                 Half Week   Alabama A&M University  Hunstville    AL  ...
# ...                     ...                      ...         ...   ...  ...
# 26375  Overnight, Half Week    University of Wyoming     Laramie    WY  ...
# 26376   Full Day, Half Week    University of Wyoming     Laramie    WY  ...
# 26377  Overnight, Half Week    University of Wyoming     Laramie    WY  ...
# 26378   Full Day, Half Week    University of Wyoming     Laramie    WY  ...
# 26379  Overnight, Half Week    University of Wyoming     Laramie    WY  ...
#
#       0-10 11-20 21-30 31-40 41-50 51-60 61-70 71-80  81-90  90+
# 0        1     1   NaN   NaN   NaN   NaN   NaN   NaN    NaN  NaN
# 1        1   NaN   NaN   NaN   NaN   NaN   NaN   NaN    NaN  NaN
# 2        1   NaN   NaN   NaN   NaN   NaN   NaN   NaN    NaN  NaN
# 3        1   NaN   NaN   NaN   NaN   NaN   NaN   NaN    NaN  NaN
# 4        1   NaN   NaN   NaN   NaN   NaN   NaN   NaN    NaN  NaN
# ...    ...   ...   ...   ...   ...   ...   ...   ...    ...  ...
# 26375    1   NaN   NaN   NaN   NaN   NaN   NaN   NaN    NaN    1
# 26376    1   NaN   NaN   NaN   NaN   NaN   NaN   NaN    NaN    1
# 26377    1   NaN   NaN   NaN   NaN   NaN   NaN   NaN    NaN    1
# 26378    1   NaN   NaN   NaN   NaN   NaN   NaN   NaN    NaN    1
# 26379    1   NaN   NaN   NaN   NaN   NaN   NaN   NaN    NaN    1
#
# [19652 rows x 30 columns]

# %%
f_1.to_excel("final.xlsx")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-5f563d123551> in <module>
# ----> 1 f_1.to_excel("final.xlsx")
#
# NameError: name 'f_1' is not defined

# %%
np6=np
np6 = np6.dropna(subset=["Price"])

# %%
np6.shape
# Out:
# (23971, 18)

# %%
price = np6["Price"].str.extract(r'(\d\S*)',expand=True)

# %%
price
# Out:
#               0
# 0           105
# 1           100
# 2           100
# 3           100
# 4            80
# ...         ...
# 26375       NaN
# 26376  235-$275
# 26377       NaN
# 26378  235-$275
# 26379       NaN
#
# [23971 rows x 1 columns]

# %%
price[0].unique()
# Out:
# array(['105', '100', '80', ..., '175-$490', '130-$180', '235-$275'],
#       dtype=object)

# %%
price = price.rename(columns={0: "Price"})

# %%
price
# Out:
#           Price
# 0           105
# 1           100
# 2           100
# 3           100
# 4            80
# ...         ...
# 26375       NaN
# 26376  235-$275
# 26377       NaN
# 26378  235-$275
# 26379       NaN
#
# [23971 rows x 1 columns]

# %%
#price = price.apply(lambda x: pd.Series(str(x).strip('$')))

# %%
price_sp = price
price_sp = price_sp["Price"].apply(lambda x: pd.Series(str(x).split(r'\D')))
price_sp = price_sp[0].apply(lambda x: pd.Series(str(x).split("-")))

# %%
price_sp.head()
# Out:
#      0    1
# 0  105  NaN
# 1  100  NaN
# 2  100  NaN
# 3  100  NaN
# 4   80  NaN

# %%
price_sp = price_sp.rename(columns={0: "PriceFirst",1:"PriceSecond"})

# %%
price_sp["PriceFirst"].unique()
# Out:
# array(['105', '100', '80', 'nan', '150', '139', '130', '60', '125', '50',
#        '995', '75', '15', '300', '600', '3', '120', '10', '140', '190',
#        '225', '245', '250', '195', '0', '155', '205', '200', '30', '70',
#        '160', '135', '115', '90', '180', '310', '85', '275', '265', '215',
#        '165', '40', '235', '185', '45', '230', '925', '725', '400', '550',
#        '25', '199', '450', '390', '340', '499', '395', '385', '335',
#        '110', '360', '325', '65', '95', '175', '560', '255', '295', '210',
#        '170', '350', '240', '285', '220', '20', '1300', '145', '89',
#        '1500', '535', '317', '248', '500', '585', '425', '35', '495',
#        '179', '189', '229', '370', '525', '895', '1,200', '595', '83',
#        '5.00', '57.00', '37.00', '7', '113', '72.00', '62.00', '63',
#        '108', '47', '8', '4', '6', '375', '475', '62', '256', '49', '28',
#        '54', '138', '78', '169', '279', '233', '157', '680', '355', '345',
#        '610', '575', '315', '64', '55', '405', '655', '52', '38', '119',
#        '178', '72', '625', '320', '750', '850', '650', '460', '247.50',
#        '800', '700', '299', '289', '118', '349', '449', '875', '280',
#        '465', '103', '455', '440', '99', '135.97', '420', '1,225', '410',
#        '2,195', '1,695', '795', '1,950', '1,495', '549', '290', '775',
#        '56', '695', '1,395', '1,250', '260', '1,850', '2,250', '4,800',
#        '3,900', '1,350', '2,995', '3,100', '1,595', '415', '380', '480',
#        '1,079', '545', '485', '755', '765', '555', '1850', '590', '635',
#        '445', '1145', '645', '599', '649', '580', '798', '1025', '620',
#        '660', '715', '3595', '705', '2560', '2520', '759', '319', '219',
#        '159', '735', '685', '1695', '149', '69', '570', '435', '605',
#        '1560', '3300', '515', '565', '74', '206', '270', '249', '47.95',
#        '429', '490', '42', '5', '48', '1,095', '33', '205.00', '130.00',
#        '149.00', '40/week', '35/week', '50/week', '75.00', '145.00',
#        '515.00', '699', '225/team', '275/team', '470', '297', '201',
#        '1,650', '36', '399', '2,200', '1,485', '330', '175`', '251',
#        '300.00', '75/Camper', '583', '845', '57', '67.50', '79', '670',
#        '123', '19', '468', '117', '71', '232', '122', '261', '204',
#        '1,175', '84', '250,', '1000', '359', '900', '12.75', '11.25',
#        '13', '748.06', '295.00', '150/session', '179.00', '345.00',
#        '355.00', '495.00', '510.00', '275OVERNIGHT', '2', '925.00',
#        '625.00', '645.00', '395.00', '3,625.00', '1,020.00', '435.00',
#        '2,450.00', '385.00', '1,135.00', '575.00', '40/person/hr',
#        '45/each', '109', '162', '168', '510', '710', '965', '319.95',
#        '352.50', '365', '95/person', '450,', '188', '212', '129', '318',
#        '79.50', '238.50', '55/week', '400/team', '100/week', '150/week',
#        '245/team', '520', '1995', '2450', '2695', '1425', '1350', '5,130',
#        '1680', '640', '305', '3725', '2800', '2650', '355(Resident)',
#        '430', '559', '532', '476', '958', '818', '214', '209', '379',
#        '194', '152', '579', '719', '1075', '880', '2,000', '1,500',
#        '74.20', '825', '1650', '2475', '2045', '920', '675', '575/wk',
#        '352', '1440', '127', '790', '505', '59', '479', '689', '540',
#        '5.25', '3000', '2050', '259', '34', '132', '1,799', '1295',
#        '1149', '350/team', '530', '150/session;', '284', '410.00', '176',
#        '326', '50/player', '150.00', '225.00', '25/month,', '10/month,',
#        '12/month', '5/class,', '5/', '55.00', '25/month', '75/wk',
#        '50.00', '35.00', '100/team', '815', '22', '18', '32', '14', '93',
#        '29', '835', '144', '216', '27,500', '15,500', '22,000', '10,750',
#        '200/team', '25/session', '300/team', '68', '58', '25/day',
#        '50/day', '309', '172', '70/Daily', '75/clinic', '125.97',
#        '299.97', '469.97', '1,000', '409', '329', '799', '196', '17.50',
#        '389', '589.97', '690', '141', '269', '156', '1,560', '1,775',
#        '2,150', '1,290', '1,505', '1,720', '1,935', '114', '1,375', '92',
#        '142'], dtype=object)

# %%
price_sp["PriceSecond"] = price_sp["PriceSecond"].str.lstrip('$')

# %%
price_sp["PriceSecond"].unique()
# Out:
# array([nan, '317', '175', '750', '130', '100', '13', '18', '285', '310',
#        '250', '185', '300', '999,999.00', '999,999', '0', '305', '500',
#        '400', '330', '323', '324', '325', '332', '331', '327', '328',
#        '329', '318', '319', '320', '321', '322', '326', '339', '99',
#        '450', '470', '155', '465', '875', '499', '399', '295', '299',
#        '895', '315', '775', '565', '495', '595', '345', '50', '259',
#        '180', '395', '90', '69', '119', '121', '620', '60', '445', '475',
#        '98', '225', '405', '550', '435', '540', '700', '200', '85',
#        '2,050', '65', '625', '270', '800', '30', '529', '350', '45',
#        '695', '229', '135', '1,000', '40', '195', '165', '179', '189',
#        '545', '599', '95', '105', '199', '575', '80', '365', '340', '275',
#        '260', '63', '845', '425', '10', '198', '138', '645', '72', '525',
#        '585', '1,545', '1,395', '84', '114', '1,095', '899', '297', '160',
#        '150', '2,160', '485', '125', '35', '2,350', '1,650', '650', '136',
#        '88', '112', '76', '115', '210', '375', '429', '460', '385',
#        '3,100', '1,295', '1,745', '2,565', '75', '55', '995', '370',
#        '360', '390', '415', '355', '2200', '742', '14', '560', '110',
#        '120', '220', '145', '515', '82.50', '720', '335', '1400', '1200',
#        '600', '255', '144', '128', '905', '514', '170', '258', '78',
#        '235', '232', '', '205', '610', '245', '1,275', '66', '67', '129',
#        '149', '280', '368', '279', '535', '510', '70', '15', '79', '240',
#        '410', 'S195', '140', '6340', '615', '555', '785', '1025', '1000',
#        '3000', '230', '349', '469', '1715', '219', '168', '505', '1390',
#        '999999', '955', '570', '787', '630', '7.50', '930', '290', '619',
#        '1,995', '380', '82', '57', '1099', '590', '24', '89', '1070',
#        '409', '999,1000', '999,1001', '149.97', '399.97', '1,200', '455',
#        '530', '519', '449', '919', '819', '490', '725', '519.97', '780',
#        '265', '227', '188', '2850', '1600', '659', '190'], dtype=object)

# %%
price_sp1 = price_sp

# %%
price_sp1["PriceFirst"] = price_sp1["PriceFirst"].str.extract(r'(\d*)',expand=True)

# %%
price_sp["PriceFirst"].unique()
# Out:
# array(['105', '100', '80', '', '150', '139', '130', '60', '125', '50',
#        '995', '75', '15', '300', '600', '3', '120', '10', '140', '190',
#        '225', '245', '250', '195', '0', '155', '205', '200', '30', '70',
#        '160', '135', '115', '90', '180', '310', '85', '275', '265', '215',
#        '165', '40', '235', '185', '45', '230', '925', '725', '400', '550',
#        '25', '199', '450', '390', '340', '499', '395', '385', '335',
#        '110', '360', '325', '65', '95', '175', '560', '255', '295', '210',
#        '170', '350', '240', '285', '220', '20', '1300', '145', '89',
#        '1500', '535', '317', '248', '500', '585', '425', '35', '495',
#        '179', '189', '229', '370', '525', '895', '1', '595', '83', '5',
#        '57', '37', '7', '113', '72', '62', '63', '108', '47', '8', '4',
#        '6', '375', '475', '256', '49', '28', '54', '138', '78', '169',
#        '279', '233', '157', '680', '355', '345', '610', '575', '315',
#        '64', '55', '405', '655', '52', '38', '119', '178', '625', '320',
#        '750', '850', '650', '460', '247', '800', '700', '299', '289',
#        '118', '349', '449', '875', '280', '465', '103', '455', '440',
#        '99', '420', '410', '2', '795', '549', '290', '775', '56', '695',
#        '260', '415', '380', '480', '545', '485', '755', '765', '555',
#        '1850', '590', '635', '445', '1145', '645', '599', '649', '580',
#        '798', '1025', '620', '660', '715', '3595', '705', '2560', '2520',
#        '759', '319', '219', '159', '735', '685', '1695', '149', '69',
#        '570', '435', '605', '1560', '3300', '515', '565', '74', '206',
#        '270', '249', '429', '490', '42', '48', '33', '699', '470', '297',
#        '201', '36', '399', '330', '251', '583', '845', '67', '79', '670',
#        '123', '19', '468', '117', '71', '232', '122', '261', '204', '84',
#        '1000', '359', '900', '12', '11', '13', '748', '510', '109', '162',
#        '168', '710', '965', '352', '365', '188', '212', '129', '318',
#        '238', '520', '1995', '2450', '2695', '1425', '1350', '1680',
#        '640', '305', '3725', '2800', '2650', '430', '559', '532', '476',
#        '958', '818', '214', '209', '379', '194', '152', '579', '719',
#        '1075', '880', '825', '1650', '2475', '2045', '920', '675', '1440',
#        '127', '790', '505', '59', '479', '689', '540', '3000', '2050',
#        '259', '34', '132', '1295', '1149', '530', '284', '176', '326',
#        '815', '22', '18', '32', '14', '93', '29', '835', '144', '216',
#        '27', '68', '58', '309', '172', '469', '409', '329', '799', '196',
#        '17', '389', '589', '690', '141', '269', '156', '114', '92', '142'],
#       dtype=object)

# %%
price_sp1["PriceFirst"] = price_sp1["PriceFirst"].replace('', numpy.NaN)
price_sp1["PriceSecond"] = price_sp1["PriceSecond"].replace('', numpy.NaN)

# %%
from numpy import asarray
from sklearn.preprocessing import OneHotEncoder

# %%
price_sp2 = price_sp1
price_sp2
# Out:
#       PriceFirst PriceSecond
# 0            105         NaN
# 1            100         NaN
# 2            100         NaN
# 3            100         NaN
# 4             80         NaN
# ...          ...         ...
# 26375        NaN         NaN
# 26376        235         275
# 26377        NaN         NaN
# 26378        235         275
# 26379        NaN         NaN
#
# [23971 rows x 2 columns]

# %%
price_sp2 = price_sp2.reindex(price_sp2.columns.tolist() + ['0-200','201-400','401-600','601-800','801-1000','1001-1500','1501-2000','2001-2500','2501-3000','3000+'], axis=1) 
price_sp2
# Out:
#       PriceFirst PriceSecond  0-200  201-400  401-600  601-800  801-1000  \
# 0            105         NaN    NaN      NaN      NaN      NaN       NaN
# 1            100         NaN    NaN      NaN      NaN      NaN       NaN
# 2            100         NaN    NaN      NaN      NaN      NaN       NaN
# 3            100         NaN    NaN      NaN      NaN      NaN       NaN
# 4             80         NaN    NaN      NaN      NaN      NaN       NaN
# ...          ...         ...    ...      ...      ...      ...       ...
# 26375        NaN         NaN    NaN      NaN      NaN      NaN       NaN
# 26376        235         275    NaN      NaN      NaN      NaN       NaN
# 26377        NaN         NaN    NaN      NaN      NaN      NaN       NaN
# 26378        235         275    NaN      NaN      NaN      NaN       NaN
# 26379        NaN         NaN    NaN      NaN      NaN      NaN       NaN
#
#        1001-1500  1501-2000  2001-2500  2501-3000  3000+
# 0            NaN        NaN        NaN        NaN    NaN
# 1            NaN        NaN        NaN        NaN    NaN
# 2            NaN        NaN        NaN        NaN    NaN
# 3            NaN        NaN        NaN        NaN    NaN
# 4            NaN        NaN        NaN        NaN    NaN
# ...          ...        ...        ...        ...    ...
# 26375        NaN        NaN        NaN        NaN    NaN
# 26376        NaN        NaN        NaN        NaN    NaN
# 26377        NaN        NaN        NaN        NaN    NaN
# 26378        NaN        NaN        NaN        NaN    NaN
# 26379        NaN        NaN        NaN        NaN    NaN
#
# [23971 rows x 12 columns]

# %%
price_sp2["PriceFirst"] = price_sp2["PriceFirst"].replace(numpy.NaN,'0')
price_sp2["PriceSecond"] = price_sp2["PriceSecond"].replace(numpy.NaN,'0')

# %%
price_sp2["PriceFirst"] = price_sp2["PriceFirst"].astype(str).astype(int)
price_sp2["PriceSecond"] = price_sp2["PriceSecond"].astype(str).astype(int)

# %%
r,c = price_sp2.shape
r
# Out:
# 23971

# %%
for i in range(r):
    pricefirst = price_sp2["PriceFirst"].iloc[i]
    pricesecond = price_sp2["PriceSecond"].iloc[i]
    
    if (pricefirst >= 0 and pricefirst <=200):
        price_sp2["0-200"].iloc[i]="1"
    elif(pricefirst >= 201 and pricefirst <=400):
        price_sp2["201-400"].iloc[i]="1"
    elif (pricefirst >= 401 and pricefirst <=600):
        price_sp2["401-600"].iloc[i]="1"
    elif (pricefirst >= 601 and pricefirst <=800):
        price_sp2["601-800"].iloc[i]="1"
    elif (pricefirst >= 801 and pricefirst <=1000):
        price_sp2["801-1000"].iloc[i]="1"
    elif (pricefirst >= 1001 and pricefirst <=1500):
        price_sp2["1001-1500"].iloc[i]="1"
    elif (pricefirst >= 1501 and pricefirst <=2000):
        price_sp2["1501-2000"].iloc[i]="1"
    elif (pricefirst >= 2001 and pricefirst <=2500):
        price_sp2["2001-2500"].iloc[i]="1"
    elif(pricefirst >= 2501 and pricefirst <=3000):
        price_sp2["2501-3000"].iloc[i]="1"
    elif(pricefirst >= 3001):
        price_sp2["3000+"].iloc[i]="1"
        
        

    if (pricesecond >= 0 and pricesecond <=200):
        price_sp2["0-200"].iloc[i]="1"
    elif(pricesecond >= 201 and pricesecond <=400):
        price_sp2["201-400"].iloc[i]="1"
    elif (pricesecond >= 401 and pricesecond <=600):
        price_sp2["401-600"].iloc[i]="1"
    elif (pricesecond >= 601 and pricesecond <=800):
        price_sp2["601-800"].iloc[i]="1"
    elif (pricesecond >= 801 and pricesecond <=1000):
        price_sp2["801-1000"].iloc[i]="1"
    elif (pricesecond >= 1001 and pricesecond <=1500):
        price_sp2["1001-1500"].iloc[i]="1"
    elif (pricesecond >= 1501 and pricesecond <=2000):
        price_sp2["1501-2000"].iloc[i]="1"
    elif (pricesecond >= 2001 and pricesecond <=2500):
        price_sp2["2001-2500"].iloc[i]="1"
    elif(pricesecond >= 2501 and pricesecond <=3000):
        price_sp2["2501-3000"].iloc[i]="1"
    elif(pricesecond >= 3001):
        price_sp2["3000+"].iloc[i]="1"
# Out:
# /Users/veronica/opt/anaconda3/lib/python3.7/site-packages/pandas/core/indexing.py:670: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_with_indexer(indexer, value)

# %%
f_2 = np6.join(price_sp2, on=None)

# %%
f_2
# Out:
#                                         Sports Camp Name Sports Offered  \
# 0           Alabama A&M University 2016 Fundamental Camp       Baseball
# 1      Alabama A&M University 2016 Summer Skills Clin...       Baseball
# 2      Alabama A&M University 2016 Summer Skills Clin...       Baseball
# 3      Alabama A&M University 2016 Summer Skills Clin...       Baseball
# 4                   Alabama A&M University Showcase Camp       Baseball
# ...                                                  ...            ...
# 26375  University of Wyoming - Volleyball Elite Camp ...     Volleyball
# 26376  University of Wyoming - Volleyball Skills Camp...     Volleyball
# 26377  University of Wyoming - Volleyball Skills Camp...     Volleyball
# 26378  University of Wyoming - Volleyball Team Camp (...     Volleyball
# 26379  University of Wyoming - Volleyball Team Camp (...     Volleyball
#
#                                                   Skills  \
# 0                                             all skills
# 1      Techniques, drills and skill specific exercise...
# 2      Techniques, drills and skill specific exercise...
# 3      Techniques, drills and skill specific exercise...
# 4                                             all skills
# ...                                                  ...
# 26375  Camp will involve more advanced skill instruct...
# 26376  Camp are designed for the beginner to intermed...
# 26377  Camp are designed for the beginner to intermed...
# 26378  Camp is a great opportunity for Middle & High ...
# 26379  Camp is a great opportunity for Middle & High ...
#
#                                   Required Skill Level Gender            Age  \
# 0      Novice, Beginner, Intermediate, Advanced, Elite      B      Ages 7-14
# 1                                         Intermediate      B  not available
# 2                                         Intermediate      B  not available
# 3                                         Intermediate      B  not available
# 4      Novice, Beginner, Intermediate, Advanced, Elite      B  not available
# ...                                                ...    ...            ...
# 26375                           Intermediate, Advanced      F      Ages 0-99
# 26376                           Beginner, Intermediate      F      Ages 0-99
# 26377                           Beginner, Intermediate      F      Ages 0-99
# 26378                           Intermediate, Advanced      F      Ages 0-99
# 26379                           Intermediate, Advanced      F      Ages 0-99
#
#                    Schedule Asssociated Organization        City State  ...  \
# 0                 Half Week   Alabama A&M University  Hunstville    AL  ...
# 1                  Full Day   Alabama A&M University  Hunstville    AL  ...
# 2                  Full Day   Alabama A&M University  Hunstville    AL  ...
# 3                  Full Day   Alabama A&M University  Hunstville    AL  ...
# 4                 Half Week   Alabama A&M University  Hunstville    AL  ...
# ...                     ...                      ...         ...   ...  ...
# 26375  Overnight, Half Week    University of Wyoming     Laramie    WY  ...
# 26376   Full Day, Half Week    University of Wyoming     Laramie    WY  ...
# 26377  Overnight, Half Week    University of Wyoming     Laramie    WY  ...
# 26378   Full Day, Half Week    University of Wyoming     Laramie    WY  ...
# 26379  Overnight, Half Week    University of Wyoming     Laramie    WY  ...
#
#       201-400 401-600 601-800 801-1000 1001-1500 1501-2000 2001-2500  \
# 0         NaN     NaN     NaN      NaN       NaN       NaN       NaN
# 1         NaN     NaN     NaN      NaN       NaN       NaN       NaN
# 2         NaN     NaN     NaN      NaN       NaN       NaN       NaN
# 3         NaN     NaN     NaN      NaN       NaN       NaN       NaN
# 4         NaN     NaN     NaN      NaN       NaN       NaN       NaN
# ...       ...     ...     ...      ...       ...       ...       ...
# 26375     NaN     NaN     NaN      NaN       NaN       NaN       NaN
# 26376       1     NaN     NaN      NaN       NaN       NaN       NaN
# 26377     NaN     NaN     NaN      NaN       NaN       NaN       NaN
# 26378       1     NaN     NaN      NaN       NaN       NaN       NaN
# 26379     NaN     NaN     NaN      NaN       NaN       NaN       NaN
#
#       2501-3000  3000+  PriceASecond
# 0           NaN    NaN             0
# 1           NaN    NaN             0
# 2           NaN    NaN             0
# 3           NaN    NaN             0
# 4           NaN    NaN             0
# ...         ...    ...           ...
# 26375       NaN    NaN             0
# 26376       NaN    NaN           275
# 26377       NaN    NaN             0
# 26378       NaN    NaN           275
# 26379       NaN    NaN             0
#
# [23971 rows x 31 columns]

# %%
f_2.to_excel("final.xlsx")
